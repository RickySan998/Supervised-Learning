# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import seaborn as sb
import os
import time
import math

from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from google.colab import drive
drive.mount('/content/drive')
path_real_data = "/content/drive/My Drive/Google Drive/zipcombo.dat"
# Out:
# Mounted at /content/drive

# %%
path_real_data = "/content/drive/My Drive/zipcombo.dat"
data = np.loadtxt(path_real_data)
data_samples = data[:, 1:]; data_labels = data[:, 0]

# %%
# Model Construction Functions

def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],padding='SAME')

def build_model2(layers, nodes_per_layer, learn_rate, filter_bank, num_labels = 10, threshold = 0.5, hlactivation = "tanh", optimizer_name = "Adam"
, reg_coeff = 0, drop_prob = 0):
    """
    Constructs the model and return training, predict, loss evaluation, given the fed data and labels. This fed data and labels could
    be training or test labels
    inputs:
        layers : (1x1) number of layers in the MLP
        nodes_per_layer : (1 x L+1) array specifiying #nodes in each layer
        learn_rate : (1x1) learning rate
        num_labels: (1x1) number of classes in the problem, defaults to 10 as specificied
        threshold: (1x1) threshold posterior to consider as class 1
        hlactivation = (string) argument on the activation of hidden layers. Either "tanh", "relu" or "sigmoid". Assume all layers activation
        are identical except the output layer which will always be softmax
        optimizer_name : Name of the optimizer to use. Default is Adam Optimizer
        reg_coeff : L2 Regularization coeff, default is 0 i.e. no regularization
        drop_prob : Probability of drop out, defaults to 0 i.e. no dropout
    """
    # Construct Model
    # Here, we don't fix the batch size so that later, we can flexibly use the loss operator here to predict for whole data set
    # x = tf.placeholder(tf.float32, shape = [None, nodes_per_layer[0]]) # to hold the fed in data
    x = tf.placeholder(tf.float32, shape = [None, 16, 16, 1])
    y = tf.placeholder(tf.int64, shape = [None, num_labels]) # to hold one-hot encodings of the labels
    isTrain = tf.placeholder(tf.bool, shape = None) # to enable/ disable dropout

    # Define Hidden Layers
    # Convolutional layers
    wc1 = tf.get_variable('W0', shape=(3,3,1,filter_bank), initializer=tf.initializers.glorot_uniform())
    bc1 = tf.get_variable('B0', shape=(filter_bank), initializer=tf.initializers.glorot_uniform())

    wc2 = tf.get_variable('W1', shape=(3,3,filter_bank,2*filter_bank), initializer=tf.initializers.glorot_uniform())
    bc2 = tf.get_variable('B1', shape=(2*filter_bank), initializer=tf.initializers.glorot_uniform())
    # wc1 = tf.Variable(initial_value = np.random.normal(size = (3,3,1,32)).astype(np.float32))
    # bc1 = tf.Variable(initial_value = np.random.normal(size = (32)).astype(np.float32))
    conv1 = conv2d(x, wc1, bc1)
    conv1 = maxpool2d(conv1, k = 2)
    conv2 = conv2d(conv1, wc2, bc2)
    out = maxpool2d(conv2, k = 2)
    out_shape = out.shape; out_flatten = out_shape[1] * out_shape[2] * out_shape[3]
    # Reshape
    out = tf.reshape(out, shape = [-1, out_flatten])

    # Fully connected layers
    for layer in range(1,len(nodes_per_layer)-1):
        out_node = nodes_per_layer[layer]
        if hlactivation == 'tanh':
            out = tf.layers.dense(out, out_node, activation = tf.nn.tanh, kernel_initializer =  tf.initializers.glorot_uniform,
                                    bias_initializer = tf.initializers.glorot_uniform)
            out = tf.layers.dropout(out, rate = drop_prob, training = isTrain)
        elif hlactivation == 'relu':
            out = tf.layers.dense(out, out_node, activation = tf.nn.relu, kernel_initializer =  tf.initializers.glorot_uniform,
                                    bias_initializer = tf.initializers.glorot_uniform)
            out = tf.layers.dropout(out, rate = drop_prob, training = isTrain)
        else:
            out = tf.layers.dense(out, out_node, activation = tf.nn.sigmoid, kernel_initializer =  tf.initializers.glorot_uniform,
                                    bias_initializer = tf.initializers.glorot_uniform)
            out = tf.layers.dropout(out, rate = drop_prob, training = isTrain)
    
    # Define output layer
    out = tf.layers.dense(out, num_labels, kernel_initializer =  tf.initializers.glorot_uniform, bias_initializer = tf.initializers.glorot_uniform) # create linear layer
    out_softmax = tf.nn.softmax(out)

    # Define loss
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=out))

    # Add L2 Regularization
    L2norms = [tf.nn.l2_loss(weights) for weights in tf.trainable_variables()]
    L2 = tf.reduce_sum(L2norms)
    loss_L2 = loss + reg_coeff * L2

    # Add Predictions
    predictions = tf.reshape(tf.argmax(out,1), [-1]) # for predictions, can argmax over un-normalized probabilities, since softmax doesnt change max position

    # Add Training Optimizer and Operation
    if optimizer_name == 'Adam':
        optimizer = tf.train.AdamOptimizer(learning_rate = learn_rate)
    elif optimizer_name == 'SGD':
        optimizer = tf.train.GradientDescentOptimizer(learning_rate = learn_rate)
    elif optimizer_name == 'RMSProp':
        optimizer = tf.train.RMSPropOptimizer(learning_rate = learn_rate)
    elif optimizer_name == 'Adagrad':
        optimizer = tf.train.AdagradOptimizer(learning_rate = learn_rate)

    train_op = optimizer.minimize(loss_L2)

    # return the model as a dictionary, containing the loss evaluator (without L2), loss (with L2), predictions (in terms of labels)
    # train operation, and last layer output evaluator. ALso return the placeholders so we can feed later
    model_dict = {'loss': loss
                 ,'loss_L2': loss_L2
                 ,'predictions': predictions
                 ,'train_op': train_op
                 ,'out': out_softmax
                 , 'batch_size': batch_size
                 , 'input': x
                 , 'targets': y
                 , 'isTrain': isTrain}
    
    return model_dict


def train_model2(model, n_epochs, batch_size, x_train, y_train, y_train_oh, x_val, y_val, y_val_oh):
    """
    Performs training for n_epochs, using the given model, training data. Also evaluates training and validation acc and loss
    after every epoch.
    """
    # create arrays to store loss and accuracy at the end of every epoch
    train_acc_arr = []; train_loss_arr = []; val_acc_arr = []; val_loss_arr = []
    
    for epoch in range(n_epochs):
        # print("Processing Epoch", epoch + 1)
        nData = x_train.shape[0]
        
        # Shuffle training data
        permute = np.random.permutation(nData);
        x_train = x_train[permute,:]
        y_train = y_train[permute]
        y_train_oh = y_train_oh[permute,:]
        
        # split to batches
        if batch_size >= nData:
            num_batch = 1
        else:
            num_batch = (nData // batch_size) + 1
        
        # train on each batch
        for batch_ind in range(num_batch):
            low_ind = (batch_ind) * batch_size
            high_ind = min(low_ind + batch_size, nData)
        
            batch = x_train[low_ind:high_ind, :]
            batch_lab = y_train_oh[low_ind:high_ind, :]

            # create feed dictionary to predict
            feed_train = {model['input']: batch,
                         model['targets']: batch_lab,
                         model['isTrain']: True}

            # train
            sess.run(model['train_op'], feed_dict = feed_train)
            
        # At the end of each epoch, evaluate acc and loss, append to array
        feed_alltrain = {model['input']: x_train,
                        model['targets']: y_train_oh,
                        model['isTrain']: False}
        
        feed_val = {model['input']: x_val,
                    model['targets']: y_val_oh,
                   model['isTrain']: False}
        
        # Note: Change here to print L2 included loss as well
        train_pred, train_loss = sess.run([model['predictions'], model['loss']], feed_dict = feed_alltrain)
        train_acc = np.mean(train_pred == y_train)
        
        val_pred, val_loss = sess.run([model['predictions'], model['loss']], feed_dict = feed_val)
        val_acc = np.mean(val_pred == y_val)
        
        # print("Training acc and loss are",train_acc, "and", train_loss) 
        # print("Val acc and loss are", val_acc,"and", val_loss) # for debugging
        
        # Append these information
        train_acc_arr.append(train_acc); train_loss_arr.append(train_loss)
        val_acc_arr.append(val_acc); val_loss_arr.append(val_loss)
    
    return train_acc_arr, train_loss_arr, val_acc_arr, val_loss_arr

# %%
# Auxiliary functions to process data
def split_train_test(data_samples, data_labels, train_prop, test_prop, seed = 88):
    """
    Split to 80% train and 20% test as required, randomly by first shuffling
    """
    n_tot = data_samples.shape[0]; n_train = round(train_prop * n_tot)
    
    np.random.seed(seed)
    permute = np.random.permutation(n_tot)
    
    data_shuffled = data_samples[permute,:]
    data_shuffled_labels = data_labels[permute]
    
    train_samples = data_shuffled[:n_train, :]; train_labels = data_shuffled_labels[:n_train]
    test_samples = data_shuffled[n_train:, :]; test_labels = data_shuffled_labels[n_train:]
    
    return train_samples, train_labels, test_samples, test_labels

def process_labels_SL(train_samples, train_labels, test_samples, test_labels):

    m = train_samples.shape[0]; m2 = test_samples.shape[0]
    # normalize train and test images
    mean_dat = np.mean(train_samples, axis = 0).reshape(1,-1); 
    sd_data = np.std(train_samples, axis = 0).reshape(1,-1)
    new_train = (train_samples - mean_dat) / sd_data
    new_test = (test_samples - mean_dat) / sd_data


    # one-hot encode the labels
    max_label = 9 # there are 10 labels, 0 to 9 inclusive
    y_onehot_train = np.zeros((m,max_label+1))
    y_onehot_test = np.zeros((m2, max_label + 1))

    y_onehot_train[np.arange(m),train_labels] = 1
    y_onehot_test[np.arange(m2), test_labels] = 1

    # also return the non-one-hot encoded labels, to compare accuracy.
    return train_samples, train_labels, new_train, y_onehot_train, test_samples, test_labels, new_test, y_onehot_test

# %% [markdown]
# ### Selecting the fixed hyperparameters

# %%
train_samples, train_labels, test_samples, test_labels = split_train_test(data_samples, data_labels, 0.8, 0.2, seed = 98)
train_labels = train_labels.astype(int)
test_labels = test_labels.astype(int)

# %%
train_samples, train_labels, new_train, train_oh, test_samples, test_labels, new_test, test_oh = process_labels_SL(train_samples, train_labels, test_samples, test_labels)

# %%
# NOTE: To find the values for the fixed (non-cross validated) hyerparameters, this cell is run multiple times, and we observe the plots on the training set to see if convergence
# is obtained

# Reshape the data to be compatible with the network
new_train2 = new_train.reshape(-1, 16, 16, 1)
new_test2 = new_test.reshape(-1, 16, 16, 1)

# Construct the network
nData, dim = train_samples.shape; num_labels = 10
layers = 2; nodes_per_layer = [1000, num_labels]; learn_rate = 0.001; batch_size = nData; reg_coeff = 0; drop_prob = 0.0; filter_bank = 2
# Reset everytime we build a new model.
tf.reset_default_graph()
sess = tf.Session()
MLP = build_model2(layers, nodes_per_layer, learn_rate, filter_bank, num_labels = num_labels, reg_coeff = reg_coeff, drop_prob = drop_prob, hlactivation = 'relu', optimizer_name = "Adam")
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '

# %%
init = tf.initialize_all_variables()

sess.run(init)
start = time.time()
train_acc_arr, train_loss_arr, val_acc_arr, val_loss_arr = train_model2(MLP, 200, batch_size, new_train2, train_labels, train_oh, new_test2, test_labels, test_oh)

print(f"Final validation error rate is {1 - val_acc_arr[-1]}")
print(time.time() - start)

# %%
plot_loss_acc(train_loss_arr, train_acc_arr, title='Training Data')

# %%
plot_loss_acc(val_loss_arr, val_acc_arr, title='Validation Data')

# %% [markdown]
# ### 1) Basic Run

# %% [markdown]
# NOTE: By setting batch size to be larger than or equal to the number of data, means we use all the data for 1-step gradient descend, i.e. full batch since this gives the most stable updates

# %%
train_samples, train_labels, test_samples, test_labels = split_train_test(data_samples, data_labels, 0.8, 0.2, seed = 88) #dummy run

# %%
layer_sizes = [10, 100, 1000]; filter_banks = [2, 4, 8, 16, 32, 64]
num_classes = 10
num_iter = 20
results_train = np.zeros((len(layer_sizes), len(filter_banks),num_iter)); results_test = np.zeros((len(layer_sizes), len(filter_banks),num_iter))

num_labels = 10
# Fixed hyperparameters
learn_rate = 0.001; reg_coeff = 0; drop_prob = 0.0; n_epochs = 200; layers = 2

start = time.time()
for it in range(num_iter):
    # For each iteration re-split. But NOT re-split for every d, lest it won't be a fair comparison
    start_iter = time.time()
    train_samples, train_labels, test_samples, test_labels = split_train_test(data_samples, data_labels, 0.8, 0.2, seed = it)
    train_labels = train_labels.astype(int)
    test_labels = test_labels.astype(int)
    train_samples, train_labels, new_train, train_oh, test_samples, test_labels, new_test, test_oh = process_labels_SL(train_samples, train_labels, test_samples, test_labels)
    nData, dim = train_samples.shape
    batch_size = nData;
    new_train2 = new_train.reshape(-1, 16, 16, 1)
    new_test2 = new_test.reshape(-1, 16, 16, 1)
    print(f"Iteration {it+1}/{num_iter}")
    
    # Iterate through hyperparameters
    start_iter = time.time()
    for layer_ind in range(len(layer_sizes)):
        layer_size = layer_sizes[layer_ind]; start_d = time.time()
        for f_ind in range(len(filter_banks)):
            fb = filter_banks[f_ind]
            nodes_per_layer = [layer_size, 10];
            # Build nn
            tf.reset_default_graph()
            sess = tf.Session()
            MLP = build_model2(layers, nodes_per_layer, learn_rate, fb, num_labels = num_labels, hlactivation = 'relu')

            # Train and Predict
            init = tf.initialize_all_variables()
            sess.run(init)
            start_train = time.time()
            train_acc_arr, train_loss_arr, val_acc_arr, val_loss_arr = train_model2(MLP, 200, batch_size, new_train2, train_labels, train_oh, new_test2, test_labels, test_oh)
            print(f"Training done in {time.time() - start_train}")
            test_rate = 1 - val_acc_arr[-1]; train_rate = 1 - train_acc_arr[-1]
            
            print(f"For layer size = {layer_size}, filter size = {fb}, train rate is {train_rate}, and test rate is {test_rate}")
            
            # Append results
            results_train[layer_ind, f_ind, it] = train_rate; results_test[layer_ind, f_ind, it] = test_rate
            
        print(f"All filter sizes done in {time.time() - start_d}")
    
    print(f"Iteration done in {time.time() - start_iter}")
    
print(f"{num_iter} iterations done in {time.time() - start}")
# Out:
# Iteration 1/20
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/tf_should_use.py:247: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Training done in 11.44508981704712
# For layer size = 10, filter size = 2, train rate is 0.12032804517343376, and test rate is 0.13924731182795702
# Training done in 5.051581621170044
# For layer size = 10, filter size = 4, train rate is 0.07367571927937622, and test rate is 0.08763440860215055
# Training done in 6.2481842041015625
# For layer size = 10, filter size = 8, train rate is 0.03401452003226679, and test rate is 0.04892473118279572
# Training done in 8.422730445861816
# For layer size = 10, filter size = 16, train rate is 0.017881150847001925, and test rate is 0.029032258064516148
# Training done in 14.646674633026123
# For layer size = 10, filter size = 32, train rate is 0.0038988975531056846, and test rate is 0.01666666666666672
# Training done in 27.457557678222656
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.013440860215053752
# All filter sizes done in 80.02977776527405
# Training done in 4.355863332748413
# For layer size = 100, filter size = 2, train rate is 0.17074482387738643, and test rate is 0.18279569892473113
# Training done in 4.890182971954346
# For layer size = 100, filter size = 4, train rate is 0.06278569507932241, and test rate is 0.0741935483870968
# Training done in 6.169406414031982
# For layer size = 100, filter size = 8, train rate is 0.037913417585372367, and test rate is 0.0478494623655914
# Training done in 8.345742464065552
# For layer size = 100, filter size = 16, train rate is 0.018687819306265174, and test rate is 0.029032258064516148
# Training done in 14.896288394927979
# For layer size = 100, filter size = 32, train rate is 0.004167787039526805, and test rate is 0.01666666666666672
# Training done in 27.696211338043213
# For layer size = 100, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.018279569892473146
# All filter sizes done in 67.50596690177917
# Training done in 4.376406192779541
# For layer size = 1000, filter size = 2, train rate is 0.11199247109438026, and test rate is 0.1166666666666667
# Training done in 4.892869472503662
# For layer size = 1000, filter size = 4, train rate is 0.05781123958053236, and test rate is 0.06720430107526887
# Training done in 6.13241171836853
# For layer size = 1000, filter size = 8, train rate is 0.030115622479161108, and test rate is 0.03655913978494618
# Training done in 8.255599737167358
# For layer size = 1000, filter size = 16, train rate is 0.015998924442054308, and test rate is 0.023655913978494647
# Training done in 14.719718217849731
# For layer size = 1000, filter size = 32, train rate is 0.0029577843506318757, and test rate is 0.01935483870967747
# Training done in 27.549274444580078
# For layer size = 1000, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.016129032258064502
# All filter sizes done in 67.2311418056488
# Iteration done in 214.76732563972473
# Iteration 2/20
# Training done in 4.34990119934082
# For layer size = 10, filter size = 2, train rate is 0.14493143318096258, and test rate is 0.15752688172043006
# Training done in 4.866278171539307
# For layer size = 10, filter size = 4, train rate is 0.06224791610648028, and test rate is 0.06989247311827962
# Training done in 6.1545939445495605
# For layer size = 10, filter size = 8, train rate is 0.02863673030384517, and test rate is 0.0424731182795699
# Training done in 8.317725419998169
# For layer size = 10, filter size = 16, train rate is 0.015864479698843748, and test rate is 0.02311827956989243
# Training done in 14.796416521072388
# For layer size = 10, filter size = 32, train rate is 0.00712557139015868, and test rate is 0.015591397849462396
# Training done in 27.531382083892822
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.010752688172043001
# All filter sizes done in 67.18392133712769
# Training done in 4.3831188678741455
# For layer size = 100, filter size = 2, train rate is 0.15488034417854257, and test rate is 0.16827956989247317
# Training done in 5.04799485206604
# For layer size = 100, filter size = 4, train rate is 0.08053240118311378, and test rate is 0.08387096774193548
# Training done in 6.3141796588897705
# For layer size = 100, filter size = 8, train rate is 0.02796450658779237, and test rate is 0.033333333333333326
# Training done in 8.353629350662231
# For layer size = 100, filter size = 16, train rate is 0.016536703414896436, and test rate is 0.029032258064516148
# Training done in 14.817935705184937
# For layer size = 100, filter size = 32, train rate is 0.006318902930895431, and test rate is 0.02204301075268822
# Training done in 27.55695104598999
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.014516129032258074
# All filter sizes done in 67.6176061630249
# Training done in 4.385976791381836
# For layer size = 1000, filter size = 2, train rate is 0.10997579994622209, and test rate is 0.11505376344086027
# Training done in 4.959561347961426
# For layer size = 1000, filter size = 4, train rate is 0.07636461414358697, and test rate is 0.08225806451612905
# Training done in 6.171280384063721
# For layer size = 1000, filter size = 8, train rate is 0.03562785695079318, and test rate is 0.041935483870967794
# Training done in 8.28836727142334
# For layer size = 1000, filter size = 16, train rate is 0.012503361118580303, and test rate is 0.01935483870967747
# Training done in 14.77467942237854
# For layer size = 1000, filter size = 32, train rate is 0.0034955633234740047, and test rate is 0.013440860215053752
# Training done in 27.563504219055176
# For layer size = 1000, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.012903225806451646
# All filter sizes done in 67.32694005966187
# Iteration done in 202.12855505943298
# Iteration 3/20
# Training done in 4.439118385314941
# For layer size = 10, filter size = 2, train rate is 0.13135251411669802, and test rate is 0.12688172043010748
# Training done in 4.900144577026367
# For layer size = 10, filter size = 4, train rate is 0.060365689701532665, and test rate is 0.052688172043010795
# Training done in 6.1736345291137695
# For layer size = 10, filter size = 8, train rate is 0.031460069911266486, and test rate is 0.03548387096774197
# Training done in 8.315633296966553
# For layer size = 10, filter size = 16, train rate is 0.018284485076633494, and test rate is 0.020967741935483897
# Training done in 14.76845097541809
# For layer size = 10, filter size = 32, train rate is 0.0036300080666845647, and test rate is 0.014516129032258074
# Training done in 27.539727210998535
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.012903225806451646
# All filter sizes done in 67.34030032157898
# Training done in 4.498557090759277
# For layer size = 100, filter size = 2, train rate is 0.1275880613068029, and test rate is 0.13064516129032255
# Training done in 4.984468221664429
# For layer size = 100, filter size = 4, train rate is 0.06211347136326972, and test rate is 0.06290322580645158
# Training done in 6.233658790588379
# For layer size = 100, filter size = 8, train rate is 0.03455229900510892, and test rate is 0.03440860215053765
# Training done in 8.30421495437622
# For layer size = 100, filter size = 16, train rate is 0.019225598279107303, and test rate is 0.02473118279569897
# Training done in 14.755802631378174
# For layer size = 100, filter size = 32, train rate is 0.006184458187684871, and test rate is 0.015591397849462396
# Training done in 27.56821846961975
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.011827956989247324
# All filter sizes done in 67.66831636428833
# Training done in 4.3986029624938965
# For layer size = 1000, filter size = 2, train rate is 0.1076902393116429, and test rate is 0.10537634408602148
# Training done in 4.906785249710083
# For layer size = 1000, filter size = 4, train rate is 0.06708792686205967, and test rate is 0.06720430107526887
# Training done in 6.137247085571289
# For layer size = 1000, filter size = 8, train rate is 0.03603119118042486, and test rate is 0.03655913978494618
# Training done in 8.292314291000366
# For layer size = 1000, filter size = 16, train rate is 0.018150040333422934, and test rate is 0.026881720430107503
# Training done in 14.751556396484375
# For layer size = 1000, filter size = 32, train rate is 0.0038988975531056846, and test rate is 0.016129032258064502
# Training done in 27.56486988067627
# For layer size = 1000, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.012903225806451646
# All filter sizes done in 67.23744511604309
# Iteration done in 202.24615740776062
# Iteration 4/20
# Training done in 4.381547689437866
# For layer size = 10, filter size = 2, train rate is 0.12637805861790807, and test rate is 0.1279569892473118
# Training done in 4.971609354019165
# For layer size = 10, filter size = 4, train rate is 0.06466792148426992, and test rate is 0.07634408602150533
# Training done in 6.138668775558472
# For layer size = 10, filter size = 8, train rate is 0.030384511965582117, and test rate is 0.04408602150537633
# Training done in 8.271634101867676
# For layer size = 10, filter size = 16, train rate is 0.011831137402527614, and test rate is 0.030645161290322576
# Training done in 14.681978225708008
# For layer size = 10, filter size = 32, train rate is 0.0030922290938424357, and test rate is 0.021505376344086002
# Training done in 27.519726753234863
# For layer size = 10, filter size = 64, train rate is 0.0008066684592632489, and test rate is 0.021505376344086002
# All filter sizes done in 67.139573097229
# Training done in 4.45555567741394
# For layer size = 100, filter size = 2, train rate is 0.10553912342027427, and test rate is 0.1069892473118279
# Training done in 4.99856972694397
# For layer size = 100, filter size = 4, train rate is 0.060903468674374794, and test rate is 0.07365591397849458
# Training done in 6.189038991928101
# For layer size = 100, filter size = 8, train rate is 0.03549341220758273, and test rate is 0.04892473118279572
# Training done in 8.298038721084595
# For layer size = 100, filter size = 16, train rate is 0.015730034955633188, and test rate is 0.03548387096774197
# Training done in 14.698235511779785
# For layer size = 100, filter size = 32, train rate is 0.0048400107555794936, and test rate is 0.02204301075268822
# Training done in 27.509466409683228
# For layer size = 100, filter size = 64, train rate is 0.001075557945684369, and test rate is 0.020967741935483897
# All filter sizes done in 67.30807757377625
# Training done in 4.540762186050415
# For layer size = 1000, filter size = 2, train rate is 0.15138478085506857, and test rate is 0.1483870967741936
# Training done in 5.056919574737549
# For layer size = 1000, filter size = 4, train rate is 0.06520570045711216, and test rate is 0.07688172043010755
# Training done in 6.351153612136841
# For layer size = 1000, filter size = 8, train rate is 0.03334229631621399, and test rate is 0.048387096774193505
# Training done in 8.501878499984741
# For layer size = 1000, filter size = 16, train rate is 0.01452003226673837, and test rate is 0.03118279569892468
# Training done in 14.952659845352173
# For layer size = 1000, filter size = 32, train rate is 0.004302231782737254, and test rate is 0.022580645161290325
# Training done in 27.595986366271973
# For layer size = 1000, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.019892473118279574
# All filter sizes done in 68.39263486862183
# Iteration done in 202.8403980731964
# Iteration 5/20
# Training done in 4.521470785140991
# For layer size = 10, filter size = 2, train rate is 0.14479698843775213, and test rate is 0.14032258064516134
# Training done in 5.045022010803223
# For layer size = 10, filter size = 4, train rate is 0.07448238773863947, and test rate is 0.06182795698924726
# Training done in 6.257275819778442
# For layer size = 10, filter size = 8, train rate is 0.03576230169400374, and test rate is 0.037634408602150504
# Training done in 8.402586698532104
# For layer size = 10, filter size = 16, train rate is 0.017477816617370245, and test rate is 0.02204301075268822
# Training done in 14.918295621871948
# For layer size = 10, filter size = 32, train rate is 0.002151115891368627, and test rate is 0.015591397849462396
# Training done in 27.611252307891846
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01505376344086018
# All filter sizes done in 67.96852564811707
# Training done in 4.44534158706665
# For layer size = 100, filter size = 2, train rate is 0.10742134982522178, and test rate is 0.11021505376344087
# Training done in 4.9640052318573
# For layer size = 100, filter size = 4, train rate is 0.07085237967195479, and test rate is 0.0747311827956989
# Training done in 6.224120855331421
# For layer size = 100, filter size = 8, train rate is 0.03441785426189836, and test rate is 0.04139784946236558
# Training done in 8.541544198989868
# For layer size = 100, filter size = 16, train rate is 0.013310029577843552, and test rate is 0.026344086021505397
# Training done in 14.794600486755371
# For layer size = 100, filter size = 32, train rate is 0.0029577843506318757, and test rate is 0.017204301075268824
# Training done in 27.416770458221436
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01505376344086018
# All filter sizes done in 67.56571531295776
# Training done in 4.355101108551025
# For layer size = 1000, filter size = 2, train rate is 0.1685937079860177, and test rate is 0.1596774193548387
# Training done in 4.92470908164978
# For layer size = 1000, filter size = 4, train rate is 0.07730572734606078, and test rate is 0.08225806451612905
# Training done in 6.203131675720215
# For layer size = 1000, filter size = 8, train rate is 0.04154342565205704, and test rate is 0.037634408602150504
# Training done in 8.369248867034912
# For layer size = 1000, filter size = 16, train rate is 0.017343371874159685, and test rate is 0.023655913978494647
# Training done in 14.75769591331482
# For layer size = 1000, filter size = 32, train rate is 0.0034955633234740047, and test rate is 0.018279569892473146
# Training done in 27.52678418159485
# For layer size = 1000, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.01774193548387093
# All filter sizes done in 67.27227258682251
# Iteration done in 202.80658602714539
# Iteration 6/20
# Training done in 4.371609926223755
# For layer size = 10, filter size = 2, train rate is 0.11226136058080127, and test rate is 0.12365591397849462
# Training done in 4.87977147102356
# For layer size = 10, filter size = 4, train rate is 0.07878461952137672, and test rate is 0.0903225806451613
# Training done in 6.174211502075195
# For layer size = 10, filter size = 8, train rate is 0.02930895401989786, and test rate is 0.03870967741935483
# Training done in 8.206371307373047
# For layer size = 10, filter size = 16, train rate is 0.017881150847001925, and test rate is 0.030645161290322576
# Training done in 14.680018901824951
# For layer size = 10, filter size = 32, train rate is 0.0048400107555794936, and test rate is 0.015591397849462396
# Training done in 27.560341835021973
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.018817204301075252
# All filter sizes done in 67.06558465957642
# Training done in 4.359992742538452
# For layer size = 100, filter size = 2, train rate is 0.16496369991933313, and test rate is 0.16935483870967738
# Training done in 4.8734331130981445
# For layer size = 100, filter size = 4, train rate is 0.07139015864479703, and test rate is 0.07580645161290323
# Training done in 6.168943405151367
# For layer size = 100, filter size = 8, train rate is 0.0410056466792148, and test rate is 0.04677419354838708
# Training done in 8.306381702423096
# For layer size = 100, filter size = 16, train rate is 0.014923366496369939, and test rate is 0.02849462365591393
# Training done in 14.80324125289917
# For layer size = 100, filter size = 32, train rate is 0.0053777897284216225, and test rate is 0.014516129032258074
# Training done in 27.54804563522339
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01666666666666672
# All filter sizes done in 67.42992877960205
# Training done in 4.473405599594116
# For layer size = 1000, filter size = 2, train rate is 0.10890024200053783, and test rate is 0.11612903225806448
# Training done in 4.876080513000488
# For layer size = 1000, filter size = 4, train rate is 0.0666845926324281, and test rate is 0.06290322580645158
# Training done in 6.165781497955322
# For layer size = 1000, filter size = 8, train rate is 0.031056735681634806, and test rate is 0.03655913978494618
# Training done in 8.22522783279419
# For layer size = 1000, filter size = 16, train rate is 0.015057811239580499, and test rate is 0.026881720430107503
# Training done in 14.700320720672607
# For layer size = 1000, filter size = 32, train rate is 0.004571121269158374, and test rate is 0.015591397849462396
# Training done in 27.47928524017334
# For layer size = 1000, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01666666666666672
# All filter sizes done in 67.10762214660645
# Iteration done in 201.60323095321655
# Iteration 7/20
# Training done in 4.493886232376099
# For layer size = 10, filter size = 2, train rate is 0.1218069373487497, and test rate is 0.13494623655913973
# Training done in 4.884551286697388
# For layer size = 10, filter size = 4, train rate is 0.059424576499058857, and test rate is 0.06827956989247308
# Training done in 6.098556756973267
# For layer size = 10, filter size = 8, train rate is 0.03603119118042486, and test rate is 0.04623655913978497
# Training done in 8.257130861282349
# For layer size = 10, filter size = 16, train rate is 0.013041140091422432, and test rate is 0.02741935483870972
# Training done in 14.729031324386597
# For layer size = 10, filter size = 32, train rate is 0.0032266738370529957, and test rate is 0.020967741935483897
# Training done in 27.49673342704773
# For layer size = 10, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.01935483870967747
# All filter sizes done in 67.16742634773254
# Training done in 4.374403953552246
# For layer size = 100, filter size = 2, train rate is 0.16590481312180694, and test rate is 0.1919354838709677
# Training done in 4.812489032745361
# For layer size = 100, filter size = 4, train rate is 0.07300349556332353, and test rate is 0.08225806451612905
# Training done in 6.133035182952881
# For layer size = 100, filter size = 8, train rate is 0.032401183113740295, and test rate is 0.041935483870967794
# Training done in 8.238061428070068
# For layer size = 100, filter size = 16, train rate is 0.013444474321054, and test rate is 0.02473118279569897
# Training done in 14.68954849243164
# For layer size = 100, filter size = 32, train rate is 0.0038988975531056846, and test rate is 0.023655913978494647
# Training done in 27.358766555786133
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.01774193548387093
# All filter sizes done in 66.8214361667633
# Training done in 4.322137832641602
# For layer size = 1000, filter size = 2, train rate is 0.17477816617370256, and test rate is 0.18172043010752692
# Training done in 4.879416227340698
# For layer size = 1000, filter size = 4, train rate is 0.06776015057811235, and test rate is 0.07849462365591398
# Training done in 6.128630876541138
# For layer size = 1000, filter size = 8, train rate is 0.039795643990319984, and test rate is 0.04516129032258065
# Training done in 8.31346082687378
# For layer size = 1000, filter size = 16, train rate is 0.01384780855068568, and test rate is 0.030645161290322576
# Training done in 14.725277185440063
# For layer size = 1000, filter size = 32, train rate is 0.0026888948642107557, and test rate is 0.018279569892473146
# Training done in 27.448578119277954
# For layer size = 1000, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.01774193548387093
# All filter sizes done in 67.15051555633545
# Iteration done in 201.13945198059082
# Iteration 8/20
# Training done in 4.522109031677246
# For layer size = 10, filter size = 2, train rate is 0.2718472707717128, and test rate is 0.2553763440860215
# Training done in 5.013593912124634
# For layer size = 10, filter size = 4, train rate is 0.06655014788921754, and test rate is 0.06827956989247308
# Training done in 6.24235200881958
# For layer size = 10, filter size = 8, train rate is 0.031728959397687495, and test rate is 0.04139784946236558
# Training done in 8.354970932006836
# For layer size = 10, filter size = 16, train rate is 0.011562247916106494, and test rate is 0.019892473118279574
# Training done in 14.806721925735474
# For layer size = 10, filter size = 32, train rate is 0.0033611185802635557, and test rate is 0.013440860215053752
# Training done in 27.502631425857544
# For layer size = 10, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.014516129032258074
# All filter sizes done in 67.64516711235046
# Training done in 4.399724721908569
# For layer size = 100, filter size = 2, train rate is 0.14977144393654207, and test rate is 0.14623655913978495
# Training done in 4.947367429733276
# For layer size = 100, filter size = 4, train rate is 0.060634579187953785, and test rate is 0.062365591397849474
# Training done in 6.215202808380127
# For layer size = 100, filter size = 8, train rate is 0.03495563323474049, and test rate is 0.041935483870967794
# Training done in 8.32123613357544
# For layer size = 100, filter size = 16, train rate is 0.01384780855068568, and test rate is 0.024193548387096753
# Training done in 14.8298659324646
# For layer size = 100, filter size = 32, train rate is 0.002151115891368627, and test rate is 0.017204301075268824
# Training done in 27.56141209602356
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.014516129032258074
# All filter sizes done in 67.44621157646179
# Training done in 4.414991140365601
# For layer size = 1000, filter size = 2, train rate is 0.1304114009142242, and test rate is 0.12849462365591402
# Training done in 4.953321933746338
# For layer size = 1000, filter size = 4, train rate is 0.06897015326700728, and test rate is 0.06774193548387097
# Training done in 6.196779251098633
# For layer size = 1000, filter size = 8, train rate is 0.031997848884108615, and test rate is 0.0424731182795699
# Training done in 8.284810304641724
# For layer size = 1000, filter size = 16, train rate is 0.015057811239580499, and test rate is 0.01774193548387093
# Training done in 14.707033395767212
# For layer size = 1000, filter size = 32, train rate is 0.004033342296316245, and test rate is 0.01774193548387093
# Training done in 27.473541021347046
# For layer size = 1000, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.01505376344086018
# All filter sizes done in 67.21968483924866
# Iteration done in 202.3111448287964
# Iteration 9/20
# Training done in 4.441359996795654
# For layer size = 10, filter size = 2, train rate is 0.14654477009948907, and test rate is 0.15000000000000002
# Training done in 4.965433835983276
# For layer size = 10, filter size = 4, train rate is 0.06386125302500667, and test rate is 0.06774193548387097
# Training done in 6.2002809047698975
# For layer size = 10, filter size = 8, train rate is 0.031594514654477046, and test rate is 0.03924731182795704
# Training done in 8.336773872375488
# For layer size = 10, filter size = 16, train rate is 0.01478892175315949, and test rate is 0.02741935483870972
# Training done in 14.82925295829773
# For layer size = 10, filter size = 32, train rate is 0.007663350363000809, and test rate is 0.021505376344086002
# Training done in 27.596763610839844
# For layer size = 10, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.01935483870967747
# All filter sizes done in 67.62605834007263
# Training done in 4.5446484088897705
# For layer size = 100, filter size = 2, train rate is 0.1144124764721699, and test rate is 0.11935483870967745
# Training done in 4.9804158210754395
# For layer size = 100, filter size = 4, train rate is 0.06386125302500667, and test rate is 0.0688172043010753
# Training done in 6.2277672290802
# For layer size = 100, filter size = 8, train rate is 0.03603119118042486, and test rate is 0.047311827956989294
# Training done in 8.357254028320312
# For layer size = 100, filter size = 16, train rate is 0.01438558752352781, and test rate is 0.027956989247311825
# Training done in 14.825918436050415
# For layer size = 100, filter size = 32, train rate is 0.004436676525947814, and test rate is 0.018817204301075252
# Training done in 27.59228777885437
# For layer size = 100, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.018279569892473146
# All filter sizes done in 67.96309208869934
# Training done in 4.57235050201416
# For layer size = 1000, filter size = 2, train rate is 0.15434256520570044, and test rate is 0.16236559139784945
# Training done in 5.070543050765991
# For layer size = 1000, filter size = 4, train rate is 0.07421349825221835, and test rate is 0.0854838709677419
# Training done in 6.255428075790405
# For layer size = 1000, filter size = 8, train rate is 0.04060231244958323, and test rate is 0.048387096774193505
# Training done in 8.457953214645386
# For layer size = 1000, filter size = 16, train rate is 0.01371336380747512, and test rate is 0.026344086021505397
# Training done in 14.88548755645752
# For layer size = 1000, filter size = 32, train rate is 0.004167787039526805, and test rate is 0.020967741935483897
# Training done in 27.589174509048462
# For layer size = 1000, filter size = 64, train rate is 0.0008066684592632489, and test rate is 0.019892473118279574
# All filter sizes done in 68.08698296546936
# Iteration done in 203.6762239933014
# Iteration 10/20
# Training done in 4.487982511520386
# For layer size = 10, filter size = 2, train rate is 0.184323742941651, and test rate is 0.19569892473118278
# Training done in 5.059631109237671
# For layer size = 10, filter size = 4, train rate is 0.07515461145469216, and test rate is 0.08440860215053758
# Training done in 6.397840738296509
# For layer size = 10, filter size = 8, train rate is 0.02930895401989786, and test rate is 0.037634408602150504
# Training done in 8.41468095779419
# For layer size = 10, filter size = 16, train rate is 0.015595590212422739, and test rate is 0.024193548387096753
# Training done in 14.865219354629517
# For layer size = 10, filter size = 32, train rate is 0.002285560634579187, and test rate is 0.018279569892473146
# Training done in 27.641115427017212
# For layer size = 10, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.01774193548387093
# All filter sizes done in 68.11259198188782
# Training done in 4.52538800239563
# For layer size = 100, filter size = 2, train rate is 0.14641032535627851, and test rate is 0.14784946236559138
# Training done in 5.002259016036987
# For layer size = 100, filter size = 4, train rate is 0.07125571390158647, and test rate is 0.0688172043010753
# Training done in 6.258005857467651
# For layer size = 100, filter size = 8, train rate is 0.03737563861253024, and test rate is 0.043010752688172005
# Training done in 8.372965335845947
# For layer size = 100, filter size = 16, train rate is 0.015864479698843748, and test rate is 0.026881720430107503
# Training done in 14.848113059997559
# For layer size = 100, filter size = 32, train rate is 0.004705566012368934, and test rate is 0.02204301075268822
# Training done in 27.64864706993103
# For layer size = 100, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.01666666666666672
# All filter sizes done in 67.90750789642334
# Training done in 4.584509611129761
# For layer size = 1000, filter size = 2, train rate is 0.11172358160795914, and test rate is 0.11827956989247312
# Training done in 4.985703945159912
# For layer size = 1000, filter size = 4, train rate is 0.06681903737563866, and test rate is 0.06989247311827962
# Training done in 6.320319175720215
# For layer size = 1000, filter size = 8, train rate is 0.033073406829792984, and test rate is 0.043010752688172005
# Training done in 8.443525075912476
# For layer size = 1000, filter size = 16, train rate is 0.018150040333422934, and test rate is 0.03010752688172047
# Training done in 14.873562812805176
# For layer size = 1000, filter size = 32, train rate is 0.004436676525947814, and test rate is 0.02204301075268822
# Training done in 27.61476421356201
# For layer size = 1000, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.018817204301075252
# All filter sizes done in 68.06654810905457
# Iteration done in 204.08673334121704
# Iteration 11/20
# Training done in 4.531277418136597
# For layer size = 10, filter size = 2, train rate is 0.17007260016133374, and test rate is 0.16935483870967738
# Training done in 5.065840721130371
# For layer size = 10, filter size = 4, train rate is 0.06977682172627053, and test rate is 0.07795698924731187
# Training done in 6.26158332824707
# For layer size = 10, filter size = 8, train rate is 0.04127453616563592, and test rate is 0.04892473118279572
# Training done in 8.423934936523438
# For layer size = 10, filter size = 16, train rate is 0.01398225329389624, and test rate is 0.027956989247311825
# Training done in 14.89453649520874
# For layer size = 10, filter size = 32, train rate is 0.004033342296316245, and test rate is 0.01935483870967747
# Training done in 27.607372760772705
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01505376344086018
# All filter sizes done in 68.16894245147705
# Training done in 4.497404336929321
# For layer size = 100, filter size = 2, train rate is 0.1394191987093305, and test rate is 0.14462365591397852
# Training done in 5.01087212562561
# For layer size = 100, filter size = 4, train rate is 0.06265125033611185, and test rate is 0.0639784946236559
# Training done in 6.259176254272461
# For layer size = 100, filter size = 8, train rate is 0.038854530787846175, and test rate is 0.048387096774193505
# Training done in 8.296165227890015
# For layer size = 100, filter size = 16, train rate is 0.01371336380747512, and test rate is 0.023655913978494647
# Training done in 14.800830364227295
# For layer size = 100, filter size = 32, train rate is 0.0057811239580531915, and test rate is 0.018817204301075252
# Training done in 27.624584674835205
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.01505376344086018
# All filter sizes done in 67.70730471611023
# Training done in 4.4486083984375
# For layer size = 1000, filter size = 2, train rate is 0.11817692928206502, and test rate is 0.11505376344086027
# Training done in 4.940908432006836
# For layer size = 1000, filter size = 4, train rate is 0.06157569239042748, and test rate is 0.062365591397849474
# Training done in 6.220954418182373
# For layer size = 1000, filter size = 8, train rate is 0.039930088733530544, and test rate is 0.0532258064516129
# Training done in 8.350994110107422
# For layer size = 1000, filter size = 16, train rate is 0.012772250605001312, and test rate is 0.02580645161290318
# Training done in 14.774722337722778
# For layer size = 1000, filter size = 32, train rate is 0.00658779241731644, and test rate is 0.019892473118279574
# Training done in 27.55430579185486
# For layer size = 1000, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01505376344086018
# All filter sizes done in 67.54604983329773
# Iteration done in 203.422372341156
# Iteration 12/20
# Training done in 4.399894714355469
# For layer size = 10, filter size = 2, train rate is 0.17827372949717668, and test rate is 0.18494623655913978
# Training done in 4.921939849853516
# For layer size = 10, filter size = 4, train rate is 0.07407905350900779, and test rate is 0.09193548387096773
# Training done in 6.217435121536255
# For layer size = 10, filter size = 8, train rate is 0.03576230169400374, and test rate is 0.048387096774193505
# Training done in 8.308452367782593
# For layer size = 10, filter size = 16, train rate is 0.017477816617370245, and test rate is 0.030645161290322576
# Training done in 14.867276191711426
# For layer size = 10, filter size = 32, train rate is 0.004705566012368934, and test rate is 0.020967741935483897
# Training done in 27.674323320388794
# For layer size = 10, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.01774193548387093
# All filter sizes done in 67.622878074646
# Training done in 4.612307071685791
# For layer size = 100, filter size = 2, train rate is 0.10540467867706371, and test rate is 0.12849462365591402
# Training done in 4.920008659362793
# For layer size = 100, filter size = 4, train rate is 0.06641570314600698, and test rate is 0.07580645161290323
# Training done in 6.228738307952881
# For layer size = 100, filter size = 8, train rate is 0.02836784081742405, and test rate is 0.0478494623655914
# Training done in 8.344659328460693
# For layer size = 100, filter size = 16, train rate is 0.01384780855068568, and test rate is 0.029032258064516148
# Training done in 14.929491996765137
# For layer size = 100, filter size = 32, train rate is 0.0032266738370529957, and test rate is 0.02204301075268822
# Training done in 27.59534192085266
# For layer size = 100, filter size = 64, train rate is 0.0008066684592632489, and test rate is 0.020967741935483897
# All filter sizes done in 68.00119304656982
# Training done in 4.452946186065674
# For layer size = 1000, filter size = 2, train rate is 0.13794030653401457, and test rate is 0.15322580645161288
# Training done in 4.86603307723999
# For layer size = 1000, filter size = 4, train rate is 0.08349018553374565, and test rate is 0.09892473118279566
# Training done in 6.163071155548096
# For layer size = 1000, filter size = 8, train rate is 0.0375100833557408, and test rate is 0.051075268817204256
# Training done in 8.312236785888672
# For layer size = 1000, filter size = 16, train rate is 0.011293358429685374, and test rate is 0.026881720430107503
# Training done in 14.772725343704224
# For layer size = 1000, filter size = 32, train rate is 0.0051089002420005025, and test rate is 0.02311827956989243
# Training done in 27.60162878036499
# For layer size = 1000, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.02043010752688168
# All filter sizes done in 67.38334488868713
# Iteration done in 203.00749397277832
# Iteration 13/20
# Training done in 4.479745388031006
# For layer size = 10, filter size = 2, train rate is 0.12422694272653945, and test rate is 0.12634408602150538
# Training done in 5.083268642425537
# For layer size = 10, filter size = 4, train rate is 0.06628125840279642, and test rate is 0.0693548387096774
# Training done in 6.39898419380188
# For layer size = 10, filter size = 8, train rate is 0.04235009411132029, and test rate is 0.0478494623655914
# Training done in 8.798147916793823
# For layer size = 10, filter size = 16, train rate is 0.016402258671685988, and test rate is 0.02741935483870972
# Training done in 14.930826187133789
# For layer size = 10, filter size = 32, train rate is 0.0049744554987899425, and test rate is 0.016129032258064502
# Training done in 27.72217583656311
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.013440860215053752
# All filter sizes done in 68.61292290687561
# Training done in 4.500874757766724
# For layer size = 100, filter size = 2, train rate is 0.2102715783812853, and test rate is 0.19462365591397845
# Training done in 5.021996974945068
# For layer size = 100, filter size = 4, train rate is 0.07058349018553378, and test rate is 0.06559139784946233
# Training done in 6.208642959594727
# For layer size = 100, filter size = 8, train rate is 0.03455229900510892, and test rate is 0.044623655913978544
# Training done in 8.370275020599365
# For layer size = 100, filter size = 16, train rate is 0.01438558752352781, and test rate is 0.026881720430107503
# Training done in 14.831450939178467
# For layer size = 100, filter size = 32, train rate is 0.004571121269158374, and test rate is 0.013440860215053752
# Training done in 27.56541919708252
# For layer size = 100, filter size = 64, train rate is 0.0008066684592632489, and test rate is 0.009677419354838679
# All filter sizes done in 67.74512028694153
# Training done in 4.435329914093018
# For layer size = 1000, filter size = 2, train rate is 0.11118580263511701, and test rate is 0.10268817204301073
# Training done in 4.896660327911377
# For layer size = 1000, filter size = 4, train rate is 0.0634579187953751, and test rate is 0.06559139784946233
# Training done in 6.456539869308472
# For layer size = 1000, filter size = 8, train rate is 0.026888948642108113, and test rate is 0.03279569892473122
# Training done in 8.389933109283447
# For layer size = 1000, filter size = 16, train rate is 0.01465447700994893, and test rate is 0.022580645161290325
# Training done in 14.818551301956177
# For layer size = 1000, filter size = 32, train rate is 0.0032266738370529957, and test rate is 0.013978494623655968
# Training done in 27.55004572868347
# For layer size = 1000, filter size = 64, train rate is 0.0008066684592632489, and test rate is 0.012903225806451646
# All filter sizes done in 67.77054834365845
# Iteration done in 204.12936425209045
# Iteration 14/20
# Training done in 4.475835800170898
# For layer size = 10, filter size = 2, train rate is 0.14022586716859375, and test rate is 0.1537634408602151
# Training done in 5.027100563049316
# For layer size = 10, filter size = 4, train rate is 0.05485345522990048, and test rate is 0.07258064516129037
# Training done in 6.273369550704956
# For layer size = 10, filter size = 8, train rate is 0.03482118849152993, and test rate is 0.05698924731182797
# Training done in 8.377318143844604
# For layer size = 10, filter size = 16, train rate is 0.012637805861790752, and test rate is 0.03279569892473122
# Training done in 14.913301467895508
# For layer size = 10, filter size = 32, train rate is 0.0060500134444743114, and test rate is 0.027956989247311825
# Training done in 27.63032293319702
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.02311827956989243
# All filter sizes done in 68.09392833709717
# Training done in 4.438991069793701
# For layer size = 100, filter size = 2, train rate is 0.09962355471901052, and test rate is 0.11344086021505373
# Training done in 5.072695732116699
# For layer size = 100, filter size = 4, train rate is 0.0666845926324281, and test rate is 0.08655913978494623
# Training done in 6.202295780181885
# For layer size = 100, filter size = 8, train rate is 0.03535896746437217, and test rate is 0.056451612903225756
# Training done in 8.412631273269653
# For layer size = 100, filter size = 16, train rate is 0.01357891906426456, and test rate is 0.03548387096774197
# Training done in 14.870657205581665
# For layer size = 100, filter size = 32, train rate is 0.0025544501210003068, and test rate is 0.023655913978494647
# Training done in 27.721338510513306
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.02580645161290318
# All filter sizes done in 67.90736031532288
# Training done in 4.593011140823364
# For layer size = 1000, filter size = 2, train rate is 0.09411132024737834, and test rate is 0.10268817204301073
# Training done in 5.1370556354522705
# For layer size = 1000, filter size = 4, train rate is 0.08725463834364078, and test rate is 0.1059139784946237
# Training done in 6.3120362758636475
# For layer size = 1000, filter size = 8, train rate is 0.03468674374831948, and test rate is 0.062365591397849474
# Training done in 8.540300846099854
# For layer size = 1000, filter size = 16, train rate is 0.01398225329389624, and test rate is 0.03387096774193543
# Training done in 15.004784107208252
# For layer size = 1000, filter size = 32, train rate is 0.0055122344716321825, and test rate is 0.02741935483870972
# Training done in 27.587482929229736
# For layer size = 1000, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.02311827956989243
# All filter sizes done in 68.36802554130554
# Iteration done in 204.36940932273865
# Iteration 15/20
# Training done in 4.474760055541992
# For layer size = 10, filter size = 2, train rate is 0.1554181231513848, and test rate is 0.16075268817204302
# Training done in 4.9753618240356445
# For layer size = 10, filter size = 4, train rate is 0.06735681634848079, and test rate is 0.07311827956989247
# Training done in 6.221765995025635
# For layer size = 10, filter size = 8, train rate is 0.03630008066684598, and test rate is 0.044623655913978544
# Training done in 8.330048322677612
# For layer size = 10, filter size = 16, train rate is 0.01438558752352781, and test rate is 0.02473118279569897
# Training done in 14.824852228164673
# For layer size = 10, filter size = 32, train rate is 0.004302231782737254, and test rate is 0.02043010752688168
# Training done in 27.62577724456787
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.01935483870967747
# All filter sizes done in 67.67765212059021
# Training done in 4.470221042633057
# For layer size = 100, filter size = 2, train rate is 0.18660930357623018, and test rate is 0.19999999999999996
# Training done in 4.971400022506714
# For layer size = 100, filter size = 4, train rate is 0.05633234740521642, and test rate is 0.06182795698924726
# Training done in 6.293006896972656
# For layer size = 100, filter size = 8, train rate is 0.038047862328582926, and test rate is 0.04354838709677422
# Training done in 8.344468355178833
# For layer size = 100, filter size = 16, train rate is 0.012234471632159183, and test rate is 0.024193548387096753
# Training done in 14.760186433792114
# For layer size = 100, filter size = 32, train rate is 0.0030922290938424357, and test rate is 0.020967741935483897
# Training done in 27.53797483444214
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.01774193548387093
# All filter sizes done in 67.74216032028198
# Training done in 4.4495813846588135
# For layer size = 1000, filter size = 2, train rate is 0.12328582952406564, and test rate is 0.12096774193548387
# Training done in 4.957169771194458
# For layer size = 1000, filter size = 4, train rate is 0.06292013982253297, and test rate is 0.07150537634408605
# Training done in 6.154430150985718
# For layer size = 1000, filter size = 8, train rate is 0.03697230438289867, and test rate is 0.04139784946236558
# Training done in 8.255004644393921
# For layer size = 1000, filter size = 16, train rate is 0.015192255982791059, and test rate is 0.027956989247311825
# Training done in 14.783206462860107
# For layer size = 1000, filter size = 32, train rate is 0.0037644528098951247, and test rate is 0.02043010752688168
# Training done in 27.54556155204773
# For layer size = 1000, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.016129032258064502
# All filter sizes done in 67.41352701187134
# Iteration done in 202.83343243598938
# Iteration 16/20
# Training done in 4.4063239097595215
# For layer size = 10, filter size = 2, train rate is 0.16402258671685932, and test rate is 0.17419354838709677
# Training done in 4.89147162437439
# For layer size = 10, filter size = 4, train rate is 0.07004571121269154, and test rate is 0.07258064516129037
# Training done in 6.191933631896973
# For layer size = 10, filter size = 8, train rate is 0.032535627856950744, and test rate is 0.03924731182795704
# Training done in 8.512076616287231
# For layer size = 10, filter size = 16, train rate is 0.016402258671685988, and test rate is 0.02580645161290318
# Training done in 15.009558200836182
# For layer size = 10, filter size = 32, train rate is 0.004167787039526805, and test rate is 0.018279569892473146
# Training done in 27.870118379592896
# For layer size = 10, filter size = 64, train rate is 0.00013444474321056, and test rate is 0.01505376344086018
# All filter sizes done in 68.08185768127441
# Training done in 4.720372915267944
# For layer size = 100, filter size = 2, train rate is 0.16482925517612257, and test rate is 0.1704301075268817
# Training done in 5.20648455619812
# For layer size = 100, filter size = 4, train rate is 0.0682979295509546, and test rate is 0.07365591397849458
# Training done in 6.470410346984863
# For layer size = 100, filter size = 8, train rate is 0.03482118849152993, and test rate is 0.0370967741935484
# Training done in 8.59789228439331
# For layer size = 100, filter size = 16, train rate is 0.012772250605001312, and test rate is 0.022580645161290325
# Training done in 15.005052089691162
# For layer size = 100, filter size = 32, train rate is 0.004571121269158374, and test rate is 0.02311827956989243
# Training done in 27.80135226249695
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.015591397849462396
# All filter sizes done in 69.04936838150024
# Training done in 4.610970973968506
# For layer size = 1000, filter size = 2, train rate is 0.09572465716590484, and test rate is 0.09301075268817205
# Training done in 5.123411178588867
# For layer size = 1000, filter size = 4, train rate is 0.07139015864479703, and test rate is 0.07634408602150533
# Training done in 6.3209264278411865
# For layer size = 1000, filter size = 8, train rate is 0.03616563592363542, and test rate is 0.047311827956989294
# Training done in 8.546208620071411
# For layer size = 1000, filter size = 16, train rate is 0.01357891906426456, and test rate is 0.022580645161290325
# Training done in 14.983318328857422
# For layer size = 1000, filter size = 32, train rate is 0.0057811239580531915, and test rate is 0.02580645161290318
# Training done in 27.86796522140503
# For layer size = 1000, filter size = 64, train rate is 0.00013444474321056, and test rate is 0.017204301075268824
# All filter sizes done in 68.7091965675354
# Iteration done in 205.84050464630127
# Iteration 17/20
# Training done in 4.7629101276397705
# For layer size = 10, filter size = 2, train rate is 0.12651250336111863, and test rate is 0.13978494623655913
# Training done in 5.1381659507751465
# For layer size = 10, filter size = 4, train rate is 0.0676257058349019, and test rate is 0.08118279569892473
# Training done in 6.372837781906128
# For layer size = 10, filter size = 8, train rate is 0.02877117504705562, and test rate is 0.04677419354838708
# Training done in 8.569872617721558
# For layer size = 10, filter size = 16, train rate is 0.01425114278031725, and test rate is 0.029032258064516148
# Training done in 14.95150637626648
# For layer size = 10, filter size = 32, train rate is 0.0060500134444743114, and test rate is 0.024193548387096753
# Training done in 27.575926542282104
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.02311827956989243
# All filter sizes done in 68.77145457267761
# Training done in 4.515037536621094
# For layer size = 100, filter size = 2, train rate is 0.13861253025006726, and test rate is 0.1435483870967742
# Training done in 4.940311670303345
# For layer size = 100, filter size = 4, train rate is 0.08214573810164028, and test rate is 0.10322580645161294
# Training done in 6.129008054733276
# For layer size = 100, filter size = 8, train rate is 0.033207851573003544, and test rate is 0.047311827956989294
# Training done in 8.285419225692749
# For layer size = 100, filter size = 16, train rate is 0.013175584834632992, and test rate is 0.032258064516129004
# Training done in 14.750284194946289
# For layer size = 100, filter size = 32, train rate is 0.0053777897284216225, and test rate is 0.02311827956989243
# Training done in 27.581846952438354
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.018279569892473146
# All filter sizes done in 67.38506531715393
# Training done in 4.667304754257202
# For layer size = 1000, filter size = 2, train rate is 0.13498252218338258, and test rate is 0.13548387096774195
# Training done in 5.006153583526611
# For layer size = 1000, filter size = 4, train rate is 0.06547458994353317, and test rate is 0.08064516129032262
# Training done in 6.240544557571411
# For layer size = 1000, filter size = 8, train rate is 0.02715783812852912, and test rate is 0.044623655913978544
# Training done in 8.358411073684692
# For layer size = 1000, filter size = 16, train rate is 0.009545576767948427, and test rate is 0.029569892473118253
# Training done in 14.857101917266846
# For layer size = 1000, filter size = 32, train rate is 0.0053777897284216225, and test rate is 0.02043010752688168
# Training done in 27.527395009994507
# For layer size = 1000, filter size = 64, train rate is 0.00013444474321056, and test rate is 0.022580645161290325
# All filter sizes done in 67.89734721183777
# Iteration done in 204.05398297309875
# Iteration 18/20
# Training done in 4.517201900482178
# For layer size = 10, filter size = 2, train rate is 0.18929819844044093, and test rate is 0.22526881720430103
# Training done in 5.002338171005249
# For layer size = 10, filter size = 4, train rate is 0.05915568701263785, and test rate is 0.07311827956989247
# Training done in 6.309295415878296
# For layer size = 10, filter size = 8, train rate is 0.04221564936810973, and test rate is 0.05698924731182797
# Training done in 8.374873161315918
# For layer size = 10, filter size = 16, train rate is 0.015192255982791059, and test rate is 0.03440860215053765
# Training done in 14.850896835327148
# For layer size = 10, filter size = 32, train rate is 0.0036300080666845647, and test rate is 0.02043010752688168
# Training done in 27.608169555664062
# For layer size = 10, filter size = 64, train rate is 0.00026888948642112, and test rate is 0.020967741935483897
# All filter sizes done in 67.82734274864197
# Training done in 4.47133994102478
# For layer size = 100, filter size = 2, train rate is 0.13982253293896207, and test rate is 0.15107526881720434
# Training done in 4.995218753814697
# For layer size = 100, filter size = 4, train rate is 0.07085237967195479, and test rate is 0.08924731182795698
# Training done in 6.182614803314209
# For layer size = 100, filter size = 8, train rate is 0.031997848884108615, and test rate is 0.04516129032258065
# Training done in 8.350016593933105
# For layer size = 100, filter size = 16, train rate is 0.012100026888948623, and test rate is 0.027956989247311825
# Training done in 14.806190252304077
# For layer size = 100, filter size = 32, train rate is 0.002016671148158067, and test rate is 0.021505376344086002
# Training done in 27.515637636184692
# For layer size = 100, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.021505376344086002
# All filter sizes done in 67.6551206111908
# Training done in 4.426869869232178
# For layer size = 1000, filter size = 2, train rate is 0.12637805861790807, and test rate is 0.15268817204301077
# Training done in 4.977365493774414
# For layer size = 1000, filter size = 4, train rate is 0.06332347405216454, and test rate is 0.0795698924731183
# Training done in 6.15566611289978
# For layer size = 1000, filter size = 8, train rate is 0.039392309760688304, and test rate is 0.0424731182795699
# Training done in 8.30800461769104
# For layer size = 1000, filter size = 16, train rate is 0.018956708792686183, and test rate is 0.027956989247311825
# Training done in 14.815473318099976
# For layer size = 1000, filter size = 32, train rate is 0.004705566012368934, and test rate is 0.022580645161290325
# Training done in 27.480764865875244
# For layer size = 1000, filter size = 64, train rate is 0.0006722237160526889, and test rate is 0.019892473118279574
# All filter sizes done in 67.33548164367676
# Iteration done in 202.81846404075623
# Iteration 19/20
# Training done in 4.431710243225098
# For layer size = 10, filter size = 2, train rate is 0.15057811239580532, and test rate is 0.15806451612903227
# Training done in 4.900470495223999
# For layer size = 10, filter size = 4, train rate is 0.0769023931164291, and test rate is 0.07688172043010755
# Training done in 6.157313346862793
# For layer size = 10, filter size = 8, train rate is 0.031191180424845366, and test rate is 0.03387096774193543
# Training done in 8.259582281112671
# For layer size = 10, filter size = 16, train rate is 0.01438558752352781, and test rate is 0.023655913978494647
# Training done in 14.78080940246582
# For layer size = 10, filter size = 32, train rate is 0.0025544501210003068, and test rate is 0.018817204301075252
# Training done in 27.480451822280884
# For layer size = 10, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.013978494623655968
# All filter sizes done in 67.16196584701538
# Training done in 4.301917791366577
# For layer size = 100, filter size = 2, train rate is 0.10500134444743214, and test rate is 0.10430107526881716
# Training done in 4.845834970474243
# For layer size = 100, filter size = 4, train rate is 0.07098682441516535, and test rate is 0.06774193548387097
# Training done in 6.132715702056885
# For layer size = 100, filter size = 8, train rate is 0.03670341489647755, and test rate is 0.03978494623655915
# Training done in 8.211978912353516
# For layer size = 100, filter size = 16, train rate is 0.018284485076633494, and test rate is 0.024193548387096753
# Training done in 14.7284996509552
# For layer size = 100, filter size = 32, train rate is 0.0051089002420005025, and test rate is 0.01774193548387093
# Training done in 27.43141460418701
# For layer size = 100, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.012903225806451646
# All filter sizes done in 66.81922769546509
# Training done in 4.340836524963379
# For layer size = 1000, filter size = 2, train rate is 0.14923366496369994, and test rate is 0.13924731182795702
# Training done in 4.83851170539856
# For layer size = 1000, filter size = 4, train rate is 0.07044904544232322, and test rate is 0.06720430107526887
# Training done in 6.0807716846466064
# For layer size = 1000, filter size = 8, train rate is 0.038182307071793486, and test rate is 0.041935483870967794
# Training done in 8.185375213623047
# For layer size = 1000, filter size = 16, train rate is 0.013444474321054, and test rate is 0.022580645161290325
# Training done in 14.674687385559082
# For layer size = 1000, filter size = 32, train rate is 0.006318902930895431, and test rate is 0.017204301075268824
# Training done in 27.40269947052002
# For layer size = 1000, filter size = 64, train rate is 0.0005377789728421289, and test rate is 0.014516129032258074
# All filter sizes done in 66.69753503799438
# Iteration done in 200.67881631851196
# Iteration 20/20
# Training done in 4.255611896514893
# For layer size = 10, filter size = 2, train rate is 0.1368647485883302, and test rate is 0.13225806451612898
# Training done in 4.825615167617798
# For layer size = 10, filter size = 4, train rate is 0.06426458725463835, and test rate is 0.07043010752688172
# Training done in 6.113022327423096
# For layer size = 10, filter size = 8, train rate is 0.0410056466792148, and test rate is 0.04677419354838708
# Training done in 8.220085382461548
# For layer size = 10, filter size = 16, train rate is 0.016267813928475428, and test rate is 0.030645161290322576
# Training done in 14.744836330413818
# For layer size = 10, filter size = 32, train rate is 0.0034955633234740047, and test rate is 0.01666666666666672
# Training done in 27.472772359848022
# For layer size = 10, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.015591397849462396
# All filter sizes done in 66.96197557449341
# Training done in 4.367114543914795
# For layer size = 100, filter size = 2, train rate is 0.12906695348211883, and test rate is 0.12473118279569895
# Training done in 4.79820442199707
# For layer size = 100, filter size = 4, train rate is 0.05687012637805866, and test rate is 0.07526881720430112
# Training done in 6.056494235992432
# For layer size = 100, filter size = 8, train rate is 0.025947835439634304, and test rate is 0.043010752688172005
# Training done in 8.17052960395813
# For layer size = 100, filter size = 16, train rate is 0.016267813928475428, and test rate is 0.02741935483870972
# Training done in 14.726079940795898
# For layer size = 100, filter size = 32, train rate is 0.0036300080666845647, and test rate is 0.01935483870967747
# Training done in 27.393149852752686
# For layer size = 100, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.01774193548387093
# All filter sizes done in 66.73022270202637
# Training done in 4.294975280761719
# For layer size = 1000, filter size = 2, train rate is 0.1663081473514385, and test rate is 0.16935483870967738
# Training done in 4.774732351303101
# For layer size = 1000, filter size = 4, train rate is 0.0701801559559021, and test rate is 0.0849462365591398
# Training done in 6.157634019851685
# For layer size = 1000, filter size = 8, train rate is 0.03361118580263511, and test rate is 0.04623655913978497
# Training done in 8.364981412887573
# For layer size = 1000, filter size = 16, train rate is 0.014923366496369939, and test rate is 0.030645161290322576
# Training done in 14.686675310134888
# For layer size = 1000, filter size = 32, train rate is 0.0032266738370529957, and test rate is 0.018817204301075252
# Training done in 27.411668062210083
# For layer size = 1000, filter size = 64, train rate is 0.00040333422963156895, and test rate is 0.016129032258064502
# All filter sizes done in 66.8436427116394
# Iteration done in 200.5359137058258
# 20 iterations done in 4069.7234756946564

# %%
# Prints
res_train_mean = np.mean(results_train, axis = -1); res_test_mean = np.mean(results_test, axis = -1)
res_train_std = np.std(results_train, axis = -1); res_test_std = np.std(results_test, axis = -1)
# Print train
for ls_idx in range(res_train_mean.shape[0]):
  for fs_idx in range(res_train_mean.shape[1]):
    lsize = layer_sizes[ls_idx]; fsize = filter_banks[fs_idx]
    print(f"For layer size of {lsize} and filter size of {fsize}, average training error is {res_train_mean[ls_idx, fs_idx]} with std of {res_train_std[ls_idx, fs_idx]}")
    print(f"For layer size of {lsize} and filter size of {fsize}, average test error is {res_test_mean[ls_idx, fs_idx]} with std of {res_test_std[ls_idx, fs_idx]}")
# Out:
# For layer size of 10 and filter size of 2, average training error is 0.15200322667383706 with std of 0.03497962855655152
# For layer size of 10 and filter size of 2, average test error is 0.15881720430107527 with std of 0.03381177623667345
# For layer size of 10 and filter size of 4, average training error is 0.06747781661737026 with std of 0.0064170998444307865
# For layer size of 10 and filter size of 4, average test error is 0.07432795698924732 with std of 0.009287041124477053
# For layer size of 10 and filter size of 8, average training error is 0.03422290938424308 with std of 0.004444913804876396
# For layer size of 10 and filter size of 8, average test error is 0.04411290322580645 with std of 0.00624090273286096
# For layer size of 10 and filter size of 16, average training error is 0.015279645065877933 with std of 0.0019806202263923886
# For layer size of 10 and filter size of 16, average test error is 0.027123655913978507 with std of 0.00389358313050752
# For layer size of 10 and filter size of 32, average training error is 0.004261898359774136 with std of 0.0014716019683760153
# For layer size of 10 and filter size of 32, average test error is 0.018844086021505384 with std of 0.003444533489575133
# For layer size of 10 and filter size of 64, average training error is 0.0004705566012368712 with std of 0.00016189290909910786
# For layer size of 10 and filter size of 64, average test error is 0.01704301075268817 with std of 0.0034763791742639127
# For layer size of 100 and filter size of 2, average training error is 0.14131486958859907 with std of 0.029598519381282246
# For layer size of 100 and filter size of 2, average test error is 0.1474462365591398 with std of 0.02973554528650772
# For layer size of 100 and filter size of 4, average training error is 0.06745764990588869 with std of 0.006733504270988081
# For layer size of 100 and filter size of 4, average test error is 0.07451612903225806 with std of 0.010208543482868822
# For layer size of 100 and filter size of 8, average training error is 0.034498521107824684 with std of 0.0036662763478518224
# For layer size of 100 and filter size of 8, average test error is 0.04400537634408603 with std of 0.005235452290786054
# For layer size of 100 and filter size of 16, average training error is 0.014815810701801551 with std of 0.002043648545375076
# For layer size of 100 and filter size of 16, average test error is 0.027526881720430114 with std of 0.003519760710394178
# For layer size of 100 and filter size of 32, average training error is 0.00424845388545308 with std of 0.0012506974702401464
# For layer size of 100 and filter size of 32, average test error is 0.019677419354838722 with std of 0.003095018917123498
# For layer size of 100 and filter size of 64, average training error is 0.0005579456843237185 with std of 0.00018174920455225974
# For layer size of 100 and filter size of 64, average test error is 0.01698924731182796 with std of 0.0035719323100802313
# For layer size of 1000 and filter size of 2, average training error is 0.12935600968002153 with std of 0.02380056553447149
# For layer size of 1000 and filter size of 2, average test error is 0.13182795698924735 with std of 0.02459440907601948
# For layer size of 1000 and filter size of 4, average training error is 0.06938693197095994 with std of 0.007148984653671549
# For layer size of 1000 and filter size of 4, average test error is 0.07666666666666669 with std of 0.011235658759007974
# For layer size of 1000 and filter size of 8, average training error is 0.03518418929819844 with std of 0.004168025563697363
# For layer size of 1000 and filter size of 8, average test error is 0.044005376344086015 with std of 0.006639893778220872
# For layer size of 1000 and filter size of 16, average training error is 0.014634310298467318 with std of 0.0022678062609355672
# For layer size of 1000 and filter size of 16, average test error is 0.02634408602150537 with std of 0.004048354967100355
# For layer size of 1000 and filter size of 32, average training error is 0.004382898628663612 with std of 0.0010825932852485838
# For layer size of 1000 and filter size of 32, average test error is 0.01970430107526882 with std of 0.0035348184694191844
# For layer size of 1000 and filter size of 64, average training error is 0.0005041677870395112 with std of 0.00019424822905081225
# For layer size of 1000 and filter size of 64, average test error is 0.017284946236559136 with std of 0.0029558893359999394

# %%
# Plot 
size_pow = np.log10(np.array(layer_sizes)); 
fb_pow = np.log2(np.array(filter_banks))
# Test Results
size_powgrid, fb_powgrid = np.meshgrid(size_pow,fb_pow)
fig = plt.figure(figsize = (20,10))
ax = fig.gca(projection='3d')
# ax.set_zlim(0, 30)
ax.set_xlabel("Log10 of Layer Size")
ax.set_yticks(fb_pow)
ax.set_xticks(size_pow)
ax.set_ylim(fb_pow[-1],fb_pow[0])
ax.set_xlim(size_pow[-1],size_pow[0])
ax.set_ylabel("Log2 of Filter Size")
ax.set_zlabel("Average Test Error")
ax.set_title("Plot of Basic Run Average Error Rate vs Layer Size and Filter Size")
MSE_surf = ax.plot_surface(size_powgrid, fb_powgrid, (res_test_mean.T), cmap = cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(MSE_surf, shrink=0.5, aspect=5)

# %%
# Test Heatmap
fig = plt.figure(figsize = (15,8))
heat_map = plt.imshow(np.log(res_test_mean), cmap="hot", origin="lower", 
           extent=[fb_pow[0]-0.5, fb_pow[-1]+0.5, size_pow[0]-0.5, size_pow[-1]+0.5])
plt.ylabel("Log10 Layer Size")
plt.yticks(size_pow)
plt.xlabel("Log2 Filter Size")
plt.xticks(fb_pow)
plt.title("Heatmap of Log of Average Test Errors")
fig.colorbar(heat_map, shrink=0.5, aspect=5)

# %%
# Plot Train
size_pow = np.log10(np.array(layer_sizes)); 
fb_pow = np.log2(np.array(filter_banks))
# Test Results
size_powgrid, fb_powgrid = np.meshgrid(size_pow,fb_pow)
fig = plt.figure(figsize = (20,10))
ax = fig.gca(projection='3d')
# ax.set_zlim(0, 30)
ax.set_xlabel("Log10 of Layer Size")
ax.set_yticks(fb_pow)
ax.set_xticks(size_pow)
ax.set_ylim(fb_pow[-1],fb_pow[0])
ax.set_xlim(size_pow[-1],size_pow[0])
ax.set_ylabel("Log2 of Filter Size")
ax.set_zlabel("Average Train Error")
ax.set_title("Plot of Basic Run Average Error Rate vs Layer Size and Filter Size")
MSE_surf = ax.plot_surface(size_powgrid, fb_powgrid, (res_train_mean.T), cmap = cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(MSE_surf, shrink=0.5, aspect=5)

# %%
# Train Heatmap
fig = plt.figure(figsize = (15,8))
heat_map = plt.imshow(np.log(res_train_mean), cmap="hot", origin="lower", 
           extent=[fb_pow[0]-0.5, fb_pow[-1]+0.5, size_pow[0]-0.5, size_pow[-1]+0.5])
plt.ylabel("Log10 Layer Size")
plt.yticks(size_pow)
plt.xlabel("Log2 Filter Size")
plt.xticks(fb_pow)
plt.title("Heatmap of Log of Average Train Errors")
fig.colorbar(heat_map, shrink=0.5, aspect=5)

# %% [markdown]
# ### 2) Cross Validation

# %%
# Auxiliary Functions
def getSubArray(x_train, y_train,n, seed = None):
    """
    Divide the training set into n sub-arrays
    
    Inputs:
    x_train,y train: m x n and m x 1 respectively. 
    n: # of sub-arrays
    """
    res_x = []; res_y = []; sub_arr_indexes = []
    n_samples = x_train.shape[0]; inc = n_samples/n;
    
    # Set seed to get repeatable results
    if seed is not None:
        random.seed(seed)
    
    # Not needed to shuffle because already shuffled before splitting to train and test
    # shuffle the training data before splitting to sub-arrays
#     permute = random.sample(range(n_samples), n_samples)
#     x_train = x_train[permute,:]
#     y_train = y_train[permute,:]
    
    # divide into sub-arrays
    start_idx = 0; end_idx = 0
    for _ in range(n):
        end_idx += inc
        round_end = math.floor(end_idx)
        sub_arr_indexes.append((start_idx, round_end))
        res_x.append(x_train[start_idx:round_end,:])
        res_y.append(y_train[start_idx:round_end,:])
        start_idx = round_end
    
    return res_x, res_y, sub_arr_indexes

def catSubArrays(folds):
    """
    Function to concatenate multiple sub-arrays to a single m x n array
    Input:
    folds: a list of 2d arrays to concatenate
    """
    res = folds[0]
    for idx in range(1,len(folds)):
        res = np.concatenate([res,folds[idx]],axis = 0)
    return res

# %%
# Loop 20 times.
pair_errors = []; best_pairs = [];
num_iter = 20
layer_sizes = [10, 100, 1000]; filter_banks = [2, 4, 8, 16, 32, 64]
num_classes = 10; num_labels = 10
# Fixed hyperparameters
learn_rate = 0.001; reg_coeff = 0; drop_prob = 0.0; n_epochs = 200; layers = 2
all_pair_errors = np.zeros((len(layer_sizes), len(filter_banks),num_iter)) # store results of validation error of all pairs over all 20 cross validation
# Dummy Run
train_samples, train_labels, test_samples, test_labels = split_train_test(data_samples, data_labels, 0.8, 0.2, seed = 88)
train_labels = train_labels.astype(int)
test_labels = test_labels.astype(int)
train_samples, train_labels, new_train, train_oh, test_samples, test_labels, new_test, test_oh = process_labels_SL(train_samples, train_labels, test_samples, test_labels)
nData, dim = train_samples.shape
batch_size = nData;
for it in range(num_iter):
    # Do 1 Cross Validation, and iterate 20 times
    start_val = time.time()
    n = 5;
    
    # Split for every run
    train_samples, train_labels, test_samples, test_labels = split_train_test(data_samples, data_labels, 0.8, 0.2, seed = it)
    train_labels = train_labels.astype(int); test_labels = test_labels.astype(int)
    
    # Divide into sub-arrays
    x_train, y_train, sub_idxs = getSubArray(train_samples, train_labels.reshape(-1,1), n)
    
    # Convert to numpy arrays for ease of slicing
    x_train = np.array(x_train); y_train = np.array(y_train)
    
    # 1 5-fold cross validation starts here
    pairs_val_results = np.zeros((len(layer_sizes), len(filter_banks)))
    start_cv = time.time()
    for layer_ind in range(len(layer_sizes)):
        layer_size = layer_sizes[layer_ind]; start_d = time.time()
        for f_ind in range(len(filter_banks)):
            fb = filter_banks[f_ind]; nodes_per_layer = [layer_size, 10]
            # Loop through folds for a pair of hyperparameters
            val_indexes = np.arange(n); val_err = []
            start_folds = time.time()
            for val_idx in val_indexes:
                train_indexes = np.delete(val_indexes, val_idx)
                
                # Take one fold as val, rest becomes training
                val_samples = x_train[val_idx]; val_labels = y_train[val_idx].reshape(-1)
                
                # Training set
                train_mini_samples = catSubArrays(x_train[train_indexes])
                train_mini_labels = catSubArrays(y_train[train_indexes]).reshape(-1)

                # Convert data to be compatible for NN training
                train_mini_samples, train_mini_labels, new_train, train_oh, val_samples, val_labels, new_val, val_oh = process_labels_SL(train_mini_samples, train_mini_labels, val_samples, val_labels)
                new_train2 = new_train.reshape(-1, 16, 16, 1)
                new_val2 = new_val.reshape(-1, 16, 16, 1)

                # Build nn
                tf.reset_default_graph()
                sess = tf.Session()
                MLP = build_model2(layers, nodes_per_layer, learn_rate, fb, num_labels = num_labels, hlactivation = 'relu')

                # Train and Predict
                init = tf.initialize_all_variables()
                sess.run(init)
                start_train = time.time()
                train_acc_arr, train_loss_arr, val_acc_arr, val_loss_arr = train_model2(MLP, 200, batch_size, new_train2, train_mini_labels, train_oh, new_val2, val_labels, val_oh)
                print(f"Training done in {time.time() - start_train}")
                val_rate = 1 - val_acc_arr[-1]; train_rate = 1 - train_acc_arr[-1]

                # Append Results
                val_err.append(val_rate) # this is result of each/5 fold for one pair
                
            # Store this pair's results
            print(f"Time for one 5-fold over a pair is {time.time() - start_folds}")
            print(f"For Layer size = {layer_size} and filter size = {fb}, val error is {np.mean(val_err)}")
            pairs_val_results[layer_ind, f_ind] = np.mean(np.array(val_err))
            all_pair_errors[layer_ind, f_ind, it] = np.mean(np.array(val_err))
            
    # After done for all hyperparameters, re-train and re-evaluate on the best combination
    print(f"Time for one 5-fold over all pairs is {time.time() - start_cv}")
    [index_ls], [index_fb] = np.where(pairs_val_results == np.min(pairs_val_results))
    best_ls, best_fb = layer_sizes[index_ls], filter_banks[index_fb]
    
    print(f"For iteration {it+1}, best layer size is {best_ls} and best filter size is {best_fb}")
    
    # Re-train and predict

    # Adjust data
    train_samples, train_labels, new_train, train_oh, test_samples, test_labels, new_test, test_oh = process_labels_SL(train_samples, train_labels, test_samples, test_labels)
    new_train2 = new_train.reshape(-1, 16, 16, 1)
    new_test2 = new_test.reshape(-1, 16, 16, 1)

    # Build nn
    nodes_per_layer = [best_ls, 10];
    tf.reset_default_graph()
    sess = tf.Session()
    MLP = build_model2(layers, nodes_per_layer, learn_rate, best_fb, num_labels = num_labels, hlactivation = 'relu')

    # Train and Predict
    init = tf.initialize_all_variables()
    sess.run(init)
    start_train = time.time()
    train_acc_arr, train_loss_arr, val_acc_arr, val_loss_arr = train_model2(MLP, 200, batch_size, new_train2, train_labels, train_oh, new_test2, test_labels, test_oh)
    print(f"Training done in {time.time() - start_train}")
    test_rate = 1 - val_acc_arr[-1]; train_rate = 1 - train_acc_arr[-1]
    
    
    # Append results of this round of cross-validation
    pair_errors.append(test_rate); best_pairs.append([best_ls, best_fb])
    
    print(f"Time for 1 cross validation is {time.time() - start_cv}")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/legacy_tf_layers/core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1719: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/tf_should_use.py:247: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Training done in 10.498595714569092
# Training done in 3.7077646255493164
# Training done in 3.603712558746338
# Training done in 3.7129108905792236
# Training done in 3.529402732849121
# Time for one 5-fold over a pair is 26.217509984970093
# For Layer size = 10 and filter size = 2, val error is 0.14022441807492897
# Training done in 4.298822402954102
# Training done in 4.216729640960693
# Training done in 4.19076132774353
# Training done in 4.05993914604187
# Training done in 4.086226224899292
# Time for one 5-fold over a pair is 21.874528884887695
# For Layer size = 10 and filter size = 4, val error is 0.07555643534286396
# Training done in 5.187440395355225
# Training done in 5.13262152671814
# Training done in 5.113018751144409
# Training done in 5.126321792602539
# Training done in 5.146660566329956
# Time for one 5-fold over a pair is 26.753735303878784
# For Layer size = 10 and filter size = 8, val error is 0.04261954863295514
# Training done in 6.947152137756348
# Training done in 6.977099418640137
# Training done in 6.757332801818848
# Training done in 6.740760564804077
# Training done in 6.776100397109985
# Time for one 5-fold over a pair is 35.38410139083862
# For Layer size = 10 and filter size = 16, val error is 0.028905442147355954
# Training done in 12.24824595451355
# Training done in 12.506789922714233
# Training done in 12.051136493682861
# Training done in 12.207042932510376
# Training done in 12.064419746398926
# Time for one 5-fold over a pair is 62.13069009780884
# For Layer size = 10 and filter size = 32, val error is 0.02406492468779602
# Training done in 22.606710195541382
# Training done in 22.691071033477783
# Training done in 22.08382749557495
# Training done in 22.021912097930908
# Training done in 22.059894800186157
# Time for one 5-fold over a pair is 112.53379154205322
# For Layer size = 10 and filter size = 64, val error is 0.020973165281905536
# Training done in 3.699497938156128
# Training done in 3.616225242614746
# Training done in 3.7707736492156982
# Training done in 3.64825701713562
# Training done in 3.655986785888672
# Time for one 5-fold over a pair is 19.409831762313843
# For Layer size = 100 and filter size = 2, val error is 0.1366010803306072
# Training done in 4.08237624168396
# Training done in 4.178315877914429
# Training done in 4.186974763870239
# Training done in 4.18996524810791
# Training done in 4.105745315551758
# Time for one 5-fold over a pair is 21.801836490631104
# For Layer size = 100 and filter size = 4, val error is 0.08080252872565821
# Training done in 5.20842432975769
# Training done in 5.151962518692017
# Training done in 5.1831512451171875
# Training done in 5.144032955169678
# Training done in 5.171786308288574
# Time for one 5-fold over a pair is 27.085421085357666
# For Layer size = 100 and filter size = 8, val error is 0.04611435306708318
# Training done in 6.843266010284424
# Training done in 6.887134313583374
# Training done in 6.877013444900513
# Training done in 6.853235960006714
# Training done in 6.892146825790405
# Time for one 5-fold over a pair is 35.43766689300537
# For Layer size = 100 and filter size = 16, val error is 0.028502035562690244
# Training done in 11.940875053405762
# Training done in 12.011658430099487
# Training done in 11.942754983901978
# Training done in 12.204529762268066
# Training done in 12.144668340682983
# Time for one 5-fold over a pair is 61.31525492668152
# For Layer size = 100 and filter size = 32, val error is 0.023796469039923097
# Training done in 22.11951231956482
# Training done in 22.108654022216797
# Training done in 22.14605164527893
# Training done in 22.062143325805664
# Training done in 22.169026851654053
# Time for one 5-fold over a pair is 111.67917323112488
# For Layer size = 100 and filter size = 64, val error is 0.021511070857828773
# Training done in 3.6603567600250244
# Training done in 3.6007328033447266
# Training done in 3.715592861175537
# Training done in 3.5869131088256836
# Training done in 3.6464545726776123
# Time for one 5-fold over a pair is 19.21726942062378
# For Layer size = 1000 and filter size = 2, val error is 0.13660053799596503
# Training done in 4.115891695022583
# Training done in 4.099085807800293
# Training done in 4.177746772766113
# Training done in 4.055312395095825
# Training done in 4.168572902679443
# Time for one 5-fold over a pair is 21.807766437530518
# For Layer size = 1000 and filter size = 4, val error is 0.07690422731775748
# Training done in 5.146369695663452
# Training done in 5.11850643157959
# Training done in 5.105244398117065
# Training done in 5.119447469711304
# Training done in 5.109399795532227
# Time for one 5-fold over a pair is 26.663012981414795
# For Layer size = 1000 and filter size = 8, val error is 0.04275495151528297
# Training done in 6.819589138031006
# Training done in 6.8506317138671875
# Training done in 6.851239442825317
# Training done in 6.7542564868927
# Training done in 6.862122297286987
# Time for one 5-fold over a pair is 35.18236994743347
# For Layer size = 1000 and filter size = 16, val error is 0.029442986166851037
# Training done in 11.904802083969116
# Training done in 12.1138756275177
# Training done in 11.916796684265137
# Training done in 12.209903001785278
# Training done in 12.155609130859375
# Time for one 5-fold over a pair is 61.37134861946106
# For Layer size = 1000 and filter size = 32, val error is 0.024737329254976802
# Training done in 22.072688579559326
# Training done in 22.001753568649292
# Training done in 22.053868770599365
# Training done in 22.044363260269165
# Training done in 22.06804347038269
# Time for one 5-fold over a pair is 111.3007595539093
# For Layer size = 1000 and filter size = 64, val error is 0.02083902784707612
# Time for one 5-fold over all pairs is 837.169312953949
# For iteration 1, best layer size is 1000 and best filter size is 64
# Training done in 28.262666940689087
# Time for 1 cross validation is 865.6477932929993
# Training done in 3.692582607269287
# Training done in 3.5497934818267822
# Training done in 3.7214574813842773
# Training done in 3.5921807289123535
# Training done in 3.534404754638672
# Time for one 5-fold over a pair is 19.129602909088135
# For Layer size = 10 and filter size = 2, val error is 0.12409402998025901
# Training done in 4.095692873001099
# Training done in 4.0902099609375
# Training done in 4.120199203491211
# Training done in 4.1304426193237305
# Training done in 4.112610340118408
# Time for one 5-fold over a pair is 21.742153882980347
# For Layer size = 10 and filter size = 4, val error is 0.07824858450658394
# Training done in 5.147159814834595
# Training done in 5.073986768722534
# Training done in 5.013701915740967
# Training done in 5.073756456375122
# Training done in 5.14404559135437
# Time for one 5-fold over a pair is 26.526935815811157
# For Layer size = 10 and filter size = 8, val error is 0.05095297235539549
# Training done in 6.775603532791138
# Training done in 6.787531852722168
# Training done in 6.78570818901062
# Training done in 6.80467963218689
# Training done in 6.785143613815308
# Time for one 5-fold over a pair is 35.00972843170166
# For Layer size = 10 and filter size = 16, val error is 0.029847115864372963
# Training done in 11.98344087600708
# Training done in 12.176666736602783
# Training done in 12.048405885696411
# Training done in 12.177066326141357
# Training done in 12.189125776290894
# Time for one 5-fold over a pair is 61.64788293838501
# For Layer size = 10 and filter size = 32, val error is 0.02352738066830091
# Training done in 22.159099578857422
# Training done in 22.068318605422974
# Training done in 22.040647983551025
# Training done in 22.03407311439514
# Training done in 22.062326192855835
# Time for one 5-fold over a pair is 111.44132423400879
# For Layer size = 10 and filter size = 64, val error is 0.021645208292658237
# Training done in 3.5575110912323
# Training done in 3.607726812362671
# Training done in 3.5681471824645996
# Training done in 3.550934314727783
# Training done in 3.548902750015259
# Time for one 5-fold over a pair is 19.05089831352234
# For Layer size = 100 and filter size = 2, val error is 0.13108137912083942
# Training done in 4.0735344886779785
# Training done in 4.03377890586853
# Training done in 4.076417922973633
# Training done in 4.078007698059082
# Training done in 4.0497729778289795
# Time for one 5-fold over a pair is 21.347074031829834
# For Layer size = 100 and filter size = 4, val error is 0.07918555799003549
# Training done in 5.116017818450928
# Training done in 5.0396387577056885
# Training done in 5.03158164024353
# Training done in 5.077537536621094
# Training done in 5.028302192687988
# Time for one 5-fold over a pair is 26.34246015548706
# For Layer size = 100 and filter size = 8, val error is 0.04691944884338097
# Training done in 6.7315309047698975
# Training done in 6.7549426555633545
# Training done in 6.701862812042236
# Training done in 6.728976249694824
# Training done in 6.785108804702759
# Time for one 5-fold over a pair is 34.76029181480408
# For Layer size = 100 and filter size = 16, val error is 0.030922023125149155
# Training done in 11.77677035331726
# Training done in 12.103229284286499
# Training done in 11.822652578353882
# Training done in 12.139785528182983
# Training done in 12.076327800750732
# Time for one 5-fold over a pair is 60.992491722106934
# For Layer size = 100 and filter size = 32, val error is 0.024200146791909828
# Training done in 22.0681254863739
# Training done in 22.101663827896118
# Training done in 22.050016403198242
# Training done in 22.0228910446167
# Training done in 21.992527723312378
# Time for one 5-fold over a pair is 111.29908156394958
# For Layer size = 100 and filter size = 64, val error is 0.020703805742962333
# Training done in 3.592477321624756
# Training done in 3.570300340652466
# Training done in 3.60587215423584
# Training done in 3.4987478256225586
# Training done in 3.572674512863159
# Time for one 5-fold over a pair is 19.009578227996826
# For Layer size = 1000 and filter size = 2, val error is 0.16752753252200073
# Training done in 4.085851669311523
# Training done in 4.042743921279907
# Training done in 4.006410837173462
# Training done in 4.0419440269470215
# Training done in 4.081050395965576
# Time for one 5-fold over a pair is 21.314175128936768
# For Layer size = 1000 and filter size = 4, val error is 0.07958995885487848
# Training done in 5.008618116378784
# Training done in 5.021739721298218
# Training done in 5.019441604614258
# Training done in 5.044760227203369
# Training done in 4.945883274078369
# Time for one 5-fold over a pair is 26.084728002548218
# For Layer size = 1000 and filter size = 8, val error is 0.043826514379099124
# Training done in 6.747161388397217
# Training done in 6.751107454299927
# Training done in 6.712200164794922
# Training done in 6.759350776672363
# Training done in 6.735371112823486
# Time for one 5-fold over a pair is 34.75019598007202
# For Layer size = 1000 and filter size = 16, val error is 0.03092130001229292
# Training done in 11.78861403465271
# Training done in 11.963604927062988
# Training done in 11.751646757125854
# Training done in 12.06521725654602
# Training done in 11.989833116531372
# Time for one 5-fold over a pair is 60.62091779708862
# For Layer size = 1000 and filter size = 32, val error is 0.02514064545053547
# Training done in 21.979981899261475
# Training done in 21.944769620895386
# Training done in 22.01924753189087
# Training done in 21.962125539779663
# Training done in 22.060118913650513
# Time for one 5-fold over a pair is 111.24613404273987
# For Layer size = 1000 and filter size = 64, val error is 0.02299010781612687
# Time for one 5-fold over all pairs is 822.3185451030731
# For iteration 2, best layer size is 100 and best filter size is 64
# Training done in 27.51393723487854
# Time for 1 cross validation is 850.0505311489105
# Training done in 3.6271369457244873
# Training done in 3.5865399837493896
# Training done in 3.63041615486145
# Training done in 3.521923780441284
# Training done in 3.5182504653930664
# Time for one 5-fold over a pair is 18.90750288963318
# For Layer size = 10 and filter size = 2, val error is 0.15797909842289087
# Training done in 4.128332853317261
# Training done in 4.073295831680298
# Training done in 4.1186203956604
# Training done in 4.022303104400635
# Training done in 4.045307636260986
# Time for one 5-fold over a pair is 21.427042245864868
# For Layer size = 10 and filter size = 4, val error is 0.07771031737423259
# Training done in 5.078486680984497
# Training done in 5.05409574508667
# Training done in 5.054585933685303
# Training done in 5.041332006454468
# Training done in 4.999194383621216
# Time for one 5-fold over a pair is 26.29918384552002
# For Layer size = 10 and filter size = 8, val error is 0.04530916690167834
# Training done in 6.7936224937438965
# Training done in 6.752192735671997
# Training done in 6.760633945465088
# Training done in 6.694546937942505
# Training done in 6.81343936920166
# Time for one 5-fold over a pair is 34.88395619392395
# For Layer size = 10 and filter size = 16, val error is 0.028636896110375943
# Training done in 11.80047607421875
# Training done in 12.120591878890991
# Training done in 11.889096021652222
# Training done in 12.075952529907227
# Training done in 12.132524967193604
# Time for one 5-fold over a pair is 61.28716683387756
# For Layer size = 10 and filter size = 32, val error is 0.022855789603083366
# Training done in 22.02945590019226
# Training done in 22.021332025527954
# Training done in 22.109673500061035
# Training done in 22.057372093200684
# Training done in 22.008055925369263
# Time for one 5-fold over a pair is 111.30401825904846
# For Layer size = 10 and filter size = 64, val error is 0.021646292961942582
# Training done in 3.6691529750823975
# Training done in 3.6052002906799316
# Training done in 3.6437807083129883
# Training done in 3.5295257568359375
# Training done in 3.580803155899048
# Time for one 5-fold over a pair is 19.047710418701172
# For Layer size = 100 and filter size = 2, val error is 0.14533474701896726
# Training done in 4.090888261795044
# Training done in 4.09722113609314
# Training done in 4.113343238830566
# Training done in 3.9842019081115723
# Training done in 4.102384328842163
# Time for one 5-fold over a pair is 21.417901515960693
# For Layer size = 100 and filter size = 4, val error is 0.07744267522832289
# Training done in 5.060207843780518
# Training done in 5.084878206253052
# Training done in 5.10938286781311
# Training done in 5.029320478439331
# Training done in 5.116151809692383
# Time for one 5-fold over a pair is 26.45611310005188
# For Layer size = 100 and filter size = 8, val error is 0.048401830198639105
# Training done in 6.7649030685424805
# Training done in 6.7578184604644775
# Training done in 6.771075963973999
# Training done in 6.789978742599487
# Training done in 6.753225326538086
# Time for one 5-fold over a pair is 34.899710178375244
# For Layer size = 100 and filter size = 16, val error is 0.030922746238005373
# Training done in 11.902967929840088
# Training done in 12.071545600891113
# Training done in 11.805005311965942
# Training done in 12.04200005531311
# Training done in 12.108893632888794
# Time for one 5-fold over a pair is 61.15462803840637
# For Layer size = 100 and filter size = 32, val error is 0.023124516418277417
# Training done in 22.10904312133789
# Training done in 21.992498874664307
# Training done in 22.014946699142456
# Training done in 22.049537897109985
# Training done in 22.04670524597168
# Time for one 5-fold over a pair is 111.28671741485596
# For Layer size = 100 and filter size = 64, val error is 0.02178034000766498
# Training done in 3.6215946674346924
# Training done in 3.4774856567382812
# Training done in 3.6138598918914795
# Training done in 3.6008803844451904
# Training done in 3.513822078704834
# Time for one 5-fold over a pair is 18.846805572509766
# For Layer size = 1000 and filter size = 2, val error is 0.13727068283547011
# Training done in 4.084171772003174
# Training done in 4.03344988822937
# Training done in 4.084716558456421
# Training done in 4.135696172714233
# Training done in 4.037841558456421
# Time for one 5-fold over a pair is 21.413423776626587
# For Layer size = 1000 and filter size = 4, val error is 0.08134124780354471
# Training done in 5.082637548446655
# Training done in 5.033885478973389
# Training done in 5.1764349937438965
# Training done in 4.998603582382202
# Training done in 5.094439268112183
# Time for one 5-fold over a pair is 26.44210195541382
# For Layer size = 1000 and filter size = 8, val error is 0.05014950358302421
# Training done in 6.77932333946228
# Training done in 6.771611452102661
# Training done in 6.735195159912109
# Training done in 6.778029680252075
# Training done in 6.725424289703369
# Time for one 5-fold over a pair is 35.00498652458191
# For Layer size = 1000 and filter size = 16, val error is 0.028637438445018114
# Training done in 11.766275882720947
# Training done in 12.106972455978394
# Training done in 11.92849326133728
# Training done in 12.082202196121216
# Training done in 12.039657354354858
# Time for one 5-fold over a pair is 60.98512578010559
# For Layer size = 1000 and filter size = 32, val error is 0.021780611174986086
# Training done in 22.00393009185791
# Training done in 21.99448013305664
# Training done in 22.074403762817383
# Training done in 21.981563806533813
# Training done in 22.01948046684265
# Time for one 5-fold over a pair is 111.17020106315613
# For Layer size = 1000 and filter size = 64, val error is 0.020973798005654753
# Time for one 5-fold over all pairs is 822.2371604442596
# For iteration 3, best layer size is 1000 and best filter size is 64
# Training done in 27.676175832748413
# Time for 1 cross validation is 850.1239922046661
# Training done in 3.629499912261963
# Training done in 3.5816211700439453
# Training done in 3.6143579483032227
# Training done in 3.542703151702881
# Training done in 3.5438992977142334
# Time for one 5-fold over a pair is 18.90888285636902
# For Layer size = 10 and filter size = 2, val error is 0.1673821868378998
# Training done in 4.079053640365601
# Training done in 4.076832056045532
# Training done in 4.042105197906494
# Training done in 4.078335762023926
# Training done in 4.044659376144409
# Time for one 5-fold over a pair is 21.362135887145996
# For Layer size = 10 and filter size = 4, val error is 0.07690260031383096
# Training done in 5.056588172912598
# Training done in 5.059121131896973
# Training done in 5.071878910064697
# Training done in 5.066734552383423
# Training done in 5.068998336791992
# Time for one 5-fold over a pair is 26.529009103775024
# For Layer size = 10 and filter size = 8, val error is 0.04302205132655055
# Training done in 6.785018682479858
# Training done in 6.758075714111328
# Training done in 6.758679389953613
# Training done in 6.796095848083496
# Training done in 6.720066785812378
# Time for one 5-fold over a pair is 34.89494299888611
# For Layer size = 10 and filter size = 16, val error is 0.027291996586907306
# Training done in 11.897085189819336
# Training done in 12.110026359558105
# Training done in 11.794759035110474
# Training done in 12.144828796386719
# Training done in 12.197388648986816
# Time for one 5-fold over a pair is 61.211814403533936
# For Layer size = 10 and filter size = 32, val error is 0.02258615889681905
# Training done in 22.069355964660645
# Training done in 22.047276258468628
# Training done in 22.083972454071045
# Training done in 22.04010581970215
# Training done in 22.01984167098999
# Time for one 5-fold over a pair is 111.31986618041992
# For Layer size = 10 and filter size = 64, val error is 0.020300851103831775
# Training done in 3.577089548110962
# Training done in 3.593644142150879
# Training done in 3.6261675357818604
# Training done in 3.4935030937194824
# Training done in 3.6425061225891113
# Time for one 5-fold over a pair is 18.94175410270691
# For Layer size = 100 and filter size = 2, val error is 0.15205879269077524
# Training done in 4.068443536758423
# Training done in 4.172394514083862
# Training done in 4.066071033477783
# Training done in 4.122494220733643
# Training done in 4.049842834472656
# Time for one 5-fold over a pair is 21.53789186477661
# For Layer size = 100 and filter size = 4, val error is 0.06950795785698276
# Training done in 5.05988621711731
# Training done in 5.0608673095703125
# Training done in 5.054410934448242
# Training done in 5.096466541290283
# Training done in 5.0351409912109375
# Time for one 5-fold over a pair is 26.55456018447876
# For Layer size = 100 and filter size = 8, val error is 0.04140996160270734
# Training done in 6.796659231185913
# Training done in 6.715898513793945
# Training done in 6.749955177307129
# Training done in 6.749478101730347
# Training done in 6.718245983123779
# Time for one 5-fold over a pair is 34.79491591453552
# For Layer size = 100 and filter size = 16, val error is 0.028098809756238664
# Training done in 11.941806316375732
# Training done in 12.07387399673462
# Training done in 11.880325317382812
# Training done in 12.145743131637573
# Training done in 12.107303619384766
# Time for one 5-fold over a pair is 61.19975709915161
# For Layer size = 100 and filter size = 32, val error is 0.02352738066830091
# Training done in 22.058072090148926
# Training done in 22.014788389205933
# Training done in 22.03438901901245
# Training done in 22.06978440284729
# Training done in 22.070234060287476
# Time for one 5-fold over a pair is 111.29936456680298
# For Layer size = 100 and filter size = 64, val error is 0.02003212428863772
# Training done in 3.5876660346984863
# Training done in 3.6011674404144287
# Training done in 3.6866495609283447
# Training done in 3.647531270980835
# Training done in 3.5297205448150635
# Time for one 5-fold over a pair is 19.06721568107605
# For Layer size = 1000 and filter size = 2, val error is 0.14304835455669565
# Training done in 4.042580842971802
# Training done in 4.141326665878296
# Training done in 4.069792747497559
# Training done in 4.114940643310547
# Training done in 4.113541126251221
# Time for one 5-fold over a pair is 21.675877332687378
# For Layer size = 1000 and filter size = 4, val error is 0.07421524177278349
# Training done in 4.984792947769165
# Training done in 5.1096203327178955
# Training done in 5.06286358833313
# Training done in 5.095360517501831
# Training done in 5.192807912826538
# Time for one 5-fold over a pair is 26.51592206954956
# For Layer size = 1000 and filter size = 8, val error is 0.04060278687694789
# Training done in 6.771437168121338
# Training done in 6.775698900222778
# Training done in 6.783382892608643
# Training done in 6.817046403884888
# Training done in 6.768173694610596
# Time for one 5-fold over a pair is 34.98551607131958
# For Layer size = 1000 and filter size = 16, val error is 0.031191382664092382
# Training done in 11.959467649459839
# Training done in 12.14871859550476
# Training done in 11.880004644393921
# Training done in 12.091221809387207
# Training done in 12.158101081848145
# Time for one 5-fold over a pair is 61.28954219818115
# For Layer size = 1000 and filter size = 32, val error is 0.02124189209709959
# Training done in 22.04786968231201
# Training done in 22.046337604522705
# Training done in 22.030152797698975
# Training done in 22.06058979034424
# Training done in 22.098345041275024
# Time for one 5-fold over a pair is 111.33532285690308
# For Layer size = 1000 and filter size = 64, val error is 0.018552906552125603
# Time for one 5-fold over all pairs is 823.4278824329376
# For iteration 4, best layer size is 1000 and best filter size is 64
# Training done in 27.586790561676025
# Time for 1 cross validation is 851.2311127185822
# Training done in 3.5770978927612305
# Training done in 3.565124988555908
# Training done in 3.7514681816101074
# Training done in 3.467111349105835
# Training done in 3.573138952255249
# Time for one 5-fold over a pair is 18.983443021774292
# For Layer size = 10 and filter size = 2, val error is 0.1579734039091481
# Training done in 4.1334264278411865
# Training done in 4.0799431800842285
# Training done in 4.130586385726929
# Training done in 4.11115574836731
# Training done in 4.1165385246276855
# Time for one 5-fold over a pair is 21.79285454750061
# For Layer size = 10 and filter size = 4, val error is 0.0779763325162158
# Training done in 4.998738765716553
# Training done in 5.147737503051758
# Training done in 5.012035846710205
# Training done in 5.0799524784088135
# Training done in 5.163577079772949
# Time for one 5-fold over a pair is 26.4540696144104
# For Layer size = 10 and filter size = 8, val error is 0.04557482048723345
# Training done in 6.729560136795044
# Training done in 6.791946887969971
# Training done in 6.8128485679626465
# Training done in 6.762325286865234
# Training done in 6.685477018356323
# Time for one 5-fold over a pair is 34.82991981506348
# For Layer size = 10 and filter size = 16, val error is 0.02836771734964676
# Training done in 11.97278356552124
# Training done in 12.040307998657227
# Training done in 11.835387706756592
# Training done in 12.070186376571655
# Training done in 12.057039022445679
# Time for one 5-fold over a pair is 61.02794814109802
# For Layer size = 10 and filter size = 32, val error is 0.021377023812106356
# Training done in 22.03716015815735
# Training done in 22.128332138061523
# Training done in 21.98299288749695
# Training done in 22.006539583206177
# Training done in 22.13253927230835
# Time for one 5-fold over a pair is 111.3473129272461
# For Layer size = 10 and filter size = 64, val error is 0.019091083295369925
# Training done in 3.5890636444091797
# Training done in 3.5101892948150635
# Training done in 3.6351661682128906
# Training done in 3.5778210163116455
# Training done in 3.5562593936920166
# Time for one 5-fold over a pair is 19.047800064086914
# For Layer size = 100 and filter size = 2, val error is 0.13861169562733655
# Training done in 4.160559415817261
# Training done in 4.0475547313690186
# Training done in 4.074913501739502
# Training done in 4.106967449188232
# Training done in 4.039727210998535
# Time for one 5-fold over a pair is 21.49194359779358
# For Layer size = 100 and filter size = 4, val error is 0.06776010369438361
# Training done in 5.097296476364136
# Training done in 5.094213247299194
# Training done in 5.139649152755737
# Training done in 4.994769334793091
# Training done in 5.132370233535767
# Time for one 5-fold over a pair is 26.513248205184937
# For Layer size = 100 and filter size = 8, val error is 0.042754047624212685
# Training done in 6.624997854232788
# Training done in 6.599784851074219
# Training done in 6.747533559799194
# Training done in 6.602292776107788
# Training done in 6.733065843582153
# Time for one 5-fold over a pair is 34.35051345825195
# For Layer size = 100 and filter size = 16, val error is 0.028637257666804073
# Training done in 11.98340654373169
# Training done in 12.031788110733032
# Training done in 11.81350326538086
# Training done in 12.152043104171753
# Training done in 12.100337266921997
# Time for one 5-fold over a pair is 61.130234479904175
# For Layer size = 100 and filter size = 32, val error is 0.019360533223420195
# Training done in 22.037570476531982
# Training done in 22.11919403076172
# Training done in 22.036900281906128
# Training done in 22.008376836776733
# Training done in 22.080034971237183
# Time for one 5-fold over a pair is 111.53093814849854
# For Layer size = 100 and filter size = 64, val error is 0.019763578251657754
# Training done in 3.5727975368499756
# Training done in 3.5365941524505615
# Training done in 3.7084877490997314
# Training done in 3.4733314514160156
# Training done in 3.5527377128601074
# Time for one 5-fold over a pair is 18.886427879333496
# For Layer size = 1000 and filter size = 2, val error is 0.16429331988343418
# Training done in 4.129173040390015
# Training done in 4.033315896987915
# Training done in 4.065728187561035
# Training done in 4.103617906570435
# Training done in 4.0190956592559814
# Time for one 5-fold over a pair is 21.387575149536133
# For Layer size = 1000 and filter size = 4, val error is 0.07219667223463566
# Training done in 4.948115825653076
# Training done in 5.110304355621338
# Training done in 5.02013897895813
# Training done in 4.968195199966431
# Training done in 5.175700426101685
# Time for one 5-fold over a pair is 26.27509355545044
# For Layer size = 1000 and filter size = 8, val error is 0.04288773311350702
# Training done in 6.720962762832642
# Training done in 6.740838050842285
# Training done in 6.808525562286377
# Training done in 6.714893579483032
# Training done in 6.741984844207764
# Time for one 5-fold over a pair is 34.779096603393555
# For Layer size = 1000 and filter size = 16, val error is 0.028905532536462976
# Training done in 11.856953859329224
# Training done in 12.00419545173645
# Training done in 11.840635061264038
# Training done in 12.171149492263794
# Training done in 12.046294927597046
# Time for one 5-fold over a pair is 60.97738194465637
# For Layer size = 1000 and filter size = 32, val error is 0.021242615209955806
# Training done in 21.968974828720093
# Training done in 22.06907868385315
# Training done in 22.029079914093018
# Training done in 21.95233726501465
# Training done in 22.06768488883972
# Time for one 5-fold over a pair is 111.30157828330994
# For Layer size = 1000 and filter size = 64, val error is 0.01882253725838996
# Time for one 5-fold over all pairs is 822.1109409332275
# For iteration 5, best layer size is 1000 and best filter size is 64
# Training done in 27.718709707260132
# Time for 1 cross validation is 850.0424137115479
# Training done in 3.5402770042419434
# Training done in 3.4807238578796387
# Training done in 3.7377231121063232
# Training done in 3.4804365634918213
# Training done in 3.582137107849121
# Time for one 5-fold over a pair is 18.84614109992981
# For Layer size = 10 and filter size = 2, val error is 0.14977592540367773
# Training done in 3.9745917320251465
# Training done in 4.146318197250366
# Training done in 4.026125431060791
# Training done in 4.029699087142944
# Training done in 4.040520668029785
# Time for one 5-fold over a pair is 21.260963201522827
# For Layer size = 10 and filter size = 4, val error is 0.0778426470269215
# Training done in 5.077836990356445
# Training done in 4.984053373336792
# Training done in 5.1601481437683105
# Training done in 4.981434106826782
# Training done in 5.082855463027954
# Time for one 5-fold over a pair is 26.333695888519287
# For Layer size = 10 and filter size = 8, val error is 0.04248459769616242
# Training done in 6.699637174606323
# Training done in 6.831742525100708
# Training done in 6.666766405105591
# Training done in 6.760207176208496
# Training done in 6.680425405502319
# Time for one 5-fold over a pair is 34.69246554374695
# For Layer size = 10 and filter size = 16, val error is 0.030653748255490255
# Training done in 11.872591972351074
# Training done in 12.053478479385376
# Training done in 11.852151870727539
# Training done in 12.088160037994385
# Training done in 12.04529333114624
# Time for one 5-fold over a pair is 61.136679887771606
# For Layer size = 10 and filter size = 32, val error is 0.023259286576856053
# Training done in 21.977882385253906
# Training done in 22.023175716400146
# Training done in 21.974562644958496
# Training done in 21.973100662231445
# Training done in 22.026213884353638
# Time for one 5-fold over a pair is 111.04643416404724
# For Layer size = 10 and filter size = 64, val error is 0.02043598281883856
# Training done in 3.613166093826294
# Training done in 3.5543458461761475
# Training done in 3.620602607727051
# Training done in 3.4924850463867188
# Training done in 3.5894391536712646
# Time for one 5-fold over a pair is 18.890063524246216
# For Layer size = 100 and filter size = 2, val error is 0.13202567412196023
# Training done in 4.106929540634155
# Training done in 4.0704450607299805
# Training done in 4.094337701797485
# Training done in 4.01704216003418
# Training done in 4.106520652770996
# Time for one 5-fold over a pair is 21.451226472854614
# For Layer size = 100 and filter size = 4, val error is 0.0720641618037327
# Training done in 5.0482518672943115
# Training done in 5.0362229347229
# Training done in 5.110991716384888
# Training done in 4.992275714874268
# Training done in 5.059101819992065
# Time for one 5-fold over a pair is 26.296903610229492
# For Layer size = 100 and filter size = 8, val error is 0.04060305804426896
# Training done in 6.773488283157349
# Training done in 6.763685464859009
# Training done in 6.7929368019104
# Training done in 6.708386182785034
# Training done in 6.781287908554077
# Time for one 5-fold over a pair is 35.03705906867981
# For Layer size = 100 and filter size = 16, val error is 0.030922203903363178
# Training done in 11.952309370040894
# Training done in 12.023794174194336
# Training done in 11.852898359298706
# Training done in 12.160862922668457
# Training done in 12.036275148391724
# Time for one 5-fold over a pair is 61.083497762680054
# For Layer size = 100 and filter size = 32, val error is 0.022990559761661998
# Training done in 22.021283864974976
# Training done in 22.04500389099121
# Training done in 22.053964614868164
# Training done in 22.085676431655884
# Training done in 22.036884546279907
# Time for one 5-fold over a pair is 111.3209822177887
# For Layer size = 100 and filter size = 64, val error is 0.020032666623279894
# Training done in 3.6060519218444824
# Training done in 3.5852320194244385
# Training done in 3.696604013442993
# Training done in 3.5844600200653076
# Training done in 3.529716730117798
# Time for one 5-fold over a pair is 19.026428699493408
# For Layer size = 1000 and filter size = 2, val error is 0.13041900774453868
# Training done in 4.115394830703735
# Training done in 4.039276123046875
# Training done in 4.006303787231445
# Training done in 4.111567258834839
# Training done in 4.038680076599121
# Time for one 5-fold over a pair is 21.345746278762817
# For Layer size = 1000 and filter size = 4, val error is 0.07636668329826238
# Training done in 5.1055309772491455
# Training done in 4.98119592666626
# Training done in 5.091660261154175
# Training done in 5.064621686935425
# Training done in 5.083115816116333
# Time for one 5-fold over a pair is 26.38017511367798
# For Layer size = 1000 and filter size = 8, val error is 0.039526885335994376
# Training done in 6.715041160583496
# Training done in 6.771470546722412
# Training done in 6.711095333099365
# Training done in 6.730915546417236
# Training done in 6.812126398086548
# Time for one 5-fold over a pair is 34.976842403411865
# For Layer size = 1000 and filter size = 16, val error is 0.028771395101633512
# Training done in 11.924120903015137
# Training done in 12.087676286697388
# Training done in 11.85962986946106
# Training done in 12.114032745361328
# Training done in 12.05591607093811
# Time for one 5-fold over a pair is 61.10619902610779
# For Layer size = 1000 and filter size = 32, val error is 0.022587243566103355
# Training done in 22.040746212005615
# Training done in 22.063206672668457
# Training done in 22.051612377166748
# Training done in 22.106682062149048
# Training done in 21.993382215499878
# Time for one 5-fold over a pair is 111.30703639984131
# For Layer size = 1000 and filter size = 64, val error is 0.020705161579567744
# Time for one 5-fold over all pairs is 821.541469335556
# For iteration 6, best layer size is 100 and best filter size is 64
# Training done in 27.623921155929565
# Time for 1 cross validation is 849.3771214485168
# Training done in 3.5796663761138916
# Training done in 3.506568431854248
# Training done in 3.6529390811920166
# Training done in 3.56431245803833
# Training done in 3.517348289489746
# Time for one 5-fold over a pair is 18.86712908744812
# For Layer size = 10 and filter size = 2, val error is 0.14184138881055167
# Training done in 4.0179712772369385
# Training done in 4.076522350311279
# Training done in 4.008074760437012
# Training done in 4.069977045059204
# Training done in 4.009351015090942
# Time for one 5-fold over a pair is 21.234652042388916
# For Layer size = 10 and filter size = 4, val error is 0.07757581838297505
# Training done in 5.021299362182617
# Training done in 5.085440158843994
# Training done in 5.03169846534729
# Training done in 5.0125932693481445
# Training done in 5.061308145523071
# Time for one 5-fold over a pair is 26.413313150405884
# For Layer size = 10 and filter size = 8, val error is 0.044769995878256696
# Training done in 6.769829273223877
# Training done in 6.719210147857666
# Training done in 6.78923225402832
# Training done in 6.713100433349609
# Training done in 6.725222587585449
# Time for one 5-fold over a pair is 34.7845094203949
# For Layer size = 10 and filter size = 16, val error is 0.030788699192282953
# Training done in 11.819795608520508
# Training done in 12.048660278320312
# Training done in 11.926684379577637
# Training done in 12.148467063903809
# Training done in 12.1576247215271
# Time for one 5-fold over a pair is 61.16188907623291
# For Layer size = 10 and filter size = 32, val error is 0.024065376633331147
# Training done in 22.03124213218689
# Training done in 22.092716932296753
# Training done in 21.966725826263428
# Training done in 22.074944496154785
# Training done in 22.107158660888672
# Time for one 5-fold over a pair is 111.3295431137085
# For Layer size = 10 and filter size = 64, val error is 0.01976312630612258
# Training done in 3.643986225128174
# Training done in 3.5650622844696045
# Training done in 3.6176517009735107
# Training done in 3.4910404682159424
# Training done in 3.550806999206543
# Time for one 5-fold over a pair is 18.88702130317688
# For Layer size = 100 and filter size = 2, val error is 0.13902423151181204
# Training done in 4.081239223480225
# Training done in 4.069602727890015
# Training done in 4.059915542602539
# Training done in 4.06475830078125
# Training done in 4.116289854049683
# Time for one 5-fold over a pair is 21.43220281600952
# For Layer size = 100 and filter size = 4, val error is 0.06520380935852658
# Training done in 5.0347723960876465
# Training done in 5.106120824813843
# Training done in 5.002201557159424
# Training done in 5.076650142669678
# Training done in 5.009048700332642
# Time for one 5-fold over a pair is 26.456366300582886
# For Layer size = 100 and filter size = 8, val error is 0.048131114823090425
# Training done in 6.756747722625732
# Training done in 6.711500644683838
# Training done in 6.712156295776367
# Training done in 6.779144525527954
# Training done in 6.702539920806885
# Time for one 5-fold over a pair is 34.727601528167725
# For Layer size = 100 and filter size = 16, val error is 0.028233489525710274
# Training done in 11.816075801849365
# Training done in 12.047035217285156
# Training done in 11.83629035949707
# Training done in 12.083949089050293
# Training done in 12.081206798553467
# Time for one 5-fold over a pair is 60.92071223258972
# For Layer size = 100 and filter size = 32, val error is 0.022317522470732022
# Training done in 22.02841305732727
# Training done in 22.048271894454956
# Training done in 22.07086682319641
# Training done in 22.011223554611206
# Training done in 22.079527616500854
# Time for one 5-fold over a pair is 111.33452272415161
# For Layer size = 100 and filter size = 64, val error is 0.019359358165028828
# Training done in 3.6411895751953125
# Training done in 3.6230671405792236
# Training done in 3.6463797092437744
# Training done in 3.5938146114349365
# Training done in 3.5330209732055664
# Time for one 5-fold over a pair is 19.064078092575073
# For Layer size = 1000 and filter size = 2, val error is 0.16684762565893657
# Training done in 4.087569713592529
# Training done in 4.0347771644592285
# Training done in 4.115551233291626
# Training done in 4.135015964508057
# Training done in 4.05194616317749
# Time for one 5-fold over a pair is 21.631714820861816
# For Layer size = 1000 and filter size = 4, val error is 0.07502178377479371
# Training done in 5.003290176391602
# Training done in 5.0479207038879395
# Training done in 5.002126455307007
# Training done in 5.039308547973633
# Training done in 4.986127614974976
# Time for one 5-fold over a pair is 26.13854455947876
# For Layer size = 1000 and filter size = 8, val error is 0.044769724710935634
# Training done in 6.768244028091431
# Training done in 6.724353790283203
# Training done in 6.756146430969238
# Training done in 6.728116512298584
# Training done in 6.787394046783447
# Time for one 5-fold over a pair is 34.81351447105408
# For Layer size = 1000 and filter size = 16, val error is 0.027695493560680018
# Training done in 11.833852052688599
# Training done in 12.083008527755737
# Training done in 11.771896839141846
# Training done in 12.090054988861084
# Training done in 12.027217149734497
# Time for one 5-fold over a pair is 60.84818959236145
# For Layer size = 1000 and filter size = 32, val error is 0.022048705266430924
# Training done in 22.00645923614502
# Training done in 22.028459072113037
# Training done in 22.05589509010315
# Training done in 22.006263732910156
# Training done in 21.96143388748169
# Time for one 5-fold over a pair is 111.11402106285095
# For Layer size = 1000 and filter size = 64, val error is 0.021914477442494463
# Time for one 5-fold over all pairs is 821.1622867584229
# For iteration 7, best layer size is 100 and best filter size is 64
# Training done in 27.520268440246582
# Time for 1 cross validation is 848.8968441486359
# Training done in 3.7455477714538574
# Training done in 3.6012513637542725
# Training done in 3.762287139892578
# Training done in 3.7015533447265625
# Training done in 3.6253578662872314
# Time for one 5-fold over a pair is 19.614705085754395
# For Layer size = 10 and filter size = 2, val error is 0.13726977894439985
# Training done in 4.061136960983276
# Training done in 4.130083084106445
# Training done in 4.11384129524231
# Training done in 4.102583408355713
# Training done in 4.154578685760498
# Time for one 5-fold over a pair is 21.60631537437439
# For Layer size = 10 and filter size = 4, val error is 0.06856836308942735
# Training done in 5.0211005210876465
# Training done in 5.112342596054077
# Training done in 5.095372915267944
# Training done in 5.1419031620025635
# Training done in 5.017564296722412
# Time for one 5-fold over a pair is 26.447619915008545
# For Layer size = 10 and filter size = 8, val error is 0.04557590515651777
# Training done in 6.80755352973938
# Training done in 6.768521308898926
# Training done in 6.698790550231934
# Training done in 6.848997116088867
# Training done in 6.767620801925659
# Time for one 5-fold over a pair is 34.939589738845825
# For Layer size = 10 and filter size = 16, val error is 0.028502397119118374
# Training done in 11.850899696350098
# Training done in 12.134071350097656
# Training done in 11.852252721786499
# Training done in 12.113242149353027
# Training done in 12.141911268234253
# Time for one 5-fold over a pair is 61.14616632461548
# For Layer size = 10 and filter size = 32, val error is 0.02379710176367227
# Training done in 22.010291576385498
# Training done in 22.09625267982483
# Training done in 22.09379482269287
# Training done in 22.011672258377075
# Training done in 22.054199695587158
# Time for one 5-fold over a pair is 111.37308025360107
# For Layer size = 10 and filter size = 64, val error is 0.02164620257283554
# Training done in 3.638904571533203
# Training done in 3.586412191390991
# Training done in 3.594428777694702
# Training done in 3.686032295227051
# Training done in 3.531888246536255
# Time for one 5-fold over a pair is 19.235493183135986
# For Layer size = 100 and filter size = 2, val error is 0.13363631762009096
# Training done in 4.118544101715088
# Training done in 4.182426929473877
# Training done in 4.011184930801392
# Training done in 4.122657775878906
# Training done in 4.116172552108765
# Time for one 5-fold over a pair is 21.600663423538208
# For Layer size = 100 and filter size = 4, val error is 0.0684323274833503
# Training done in 5.102384328842163
# Training done in 5.151620626449585
# Training done in 5.15287184715271
# Training done in 5.039028882980347
# Training done in 5.073800086975098
# Time for one 5-fold over a pair is 26.58036184310913
# For Layer size = 100 and filter size = 8, val error is 0.04746078920537129
# Training done in 6.827372312545776
# Training done in 6.708024501800537
# Training done in 6.79839301109314
# Training done in 6.758533477783203
# Training done in 6.76081657409668
# Time for one 5-fold over a pair is 34.90637540817261
# For Layer size = 100 and filter size = 16, val error is 0.03213215249003911
# Training done in 11.898350715637207
# Training done in 12.15725588798523
# Training done in 11.838801383972168
# Training done in 12.124906063079834
# Training done in 12.14825963973999
# Time for one 5-fold over a pair is 61.22718334197998
# For Layer size = 100 and filter size = 32, val error is 0.024738775480689278
# Training done in 21.991266012191772
# Training done in 22.04564905166626
# Training done in 22.17196035385132
# Training done in 22.05372977256775
# Training done in 22.052836656570435
# Time for one 5-fold over a pair is 111.5453622341156
# For Layer size = 100 and filter size = 64, val error is 0.020704890412246657
# Training done in 3.763817310333252
# Training done in 3.494630813598633
# Training done in 3.6791884899139404
# Training done in 3.6701884269714355
# Training done in 3.5263774394989014
# Time for one 5-fold over a pair is 19.166059017181396
# For Layer size = 1000 and filter size = 2, val error is 0.13228897759073258
# Training done in 4.101852178573608
# Training done in 4.163074970245361
# Training done in 4.101568698883057
# Training done in 4.139917612075806
# Training done in 4.139508008956909
# Time for one 5-fold over a pair is 21.690969944000244
# For Layer size = 1000 and filter size = 4, val error is 0.08228436774627416
# Training done in 5.008182525634766
# Training done in 5.13494610786438
# Training done in 5.10076642036438
# Training done in 5.1024487018585205
# Training done in 5.058808326721191
# Time for one 5-fold over a pair is 26.4577317237854
# For Layer size = 1000 and filter size = 8, val error is 0.05028300829410448
# Training done in 6.841332197189331
# Training done in 6.826923847198486
# Training done in 6.893185615539551
# Training done in 6.776710510253906
# Training done in 6.77455997467041
# Time for one 5-fold over a pair is 35.1655056476593
# For Layer size = 1000 and filter size = 16, val error is 0.031192376944269705
# Training done in 11.934806108474731
# Training done in 12.103157758712769
# Training done in 11.876914501190186
# Training done in 12.14006781578064
# Training done in 12.169847011566162
# Time for one 5-fold over a pair is 61.28386998176575
# For Layer size = 1000 and filter size = 32, val error is 0.022049699546608247
# Training done in 22.04461407661438
# Training done in 22.020801544189453
# Training done in 22.052268505096436
# Training done in 22.0201358795166
# Training done in 22.09007501602173
# Time for one 5-fold over a pair is 111.46430468559265
# For Layer size = 1000 and filter size = 64, val error is 0.019628988871293183
# Time for one 5-fold over all pairs is 825.4541523456573
# For iteration 8, best layer size is 1000 and best filter size is 64
# Training done in 27.59266471862793
# Time for 1 cross validation is 853.263231754303
# Training done in 3.5838685035705566
# Training done in 3.5208568572998047
# Training done in 3.5043697357177734
# Training done in 3.5435233116149902
# Training done in 3.503718614578247
# Time for one 5-fold over a pair is 18.71687364578247
# For Layer size = 10 and filter size = 2, val error is 0.14332006421242166
# Training done in 3.995607852935791
# Training done in 3.9478771686553955
# Training done in 3.968822956085205
# Training done in 4.045132637023926
# Training done in 3.9385483264923096
# Time for one 5-fold over a pair is 20.91352653503418
# For Layer size = 10 and filter size = 4, val error is 0.07784183352495824
# Training done in 5.006292819976807
# Training done in 4.9814064502716064
# Training done in 4.974872827529907
# Training done in 5.002787828445435
# Training done in 5.001711845397949
# Time for one 5-fold over a pair is 26.01824140548706
# For Layer size = 10 and filter size = 8, val error is 0.0408710617466068
# Training done in 6.687978029251099
# Training done in 6.750396013259888
# Training done in 6.740714073181152
# Training done in 6.793096542358398
# Training done in 6.671855926513672
# ...
# For Layer size = 10 and filter size = 16, val error is 0.028502397119118394
# Training done in 11.891409635543823
# Training done in 12.031994104385376
# Training done in 11.775817394256592
# Training done in 12.045843601226807
# Training done in 12.057759761810303
# Time for one 5-fold over a pair is 61.02091908454895
# For Layer size = 10 and filter size = 32, val error is 0.022183565814116603
# Training done in 21.92488169670105
# Training done in 22.00722098350525
# Training done in 22.097736597061157
# Training done in 22.059906244277954
# Training done in 22.055338144302368
# Time for one 5-fold over a pair is 111.24424648284912
# For Layer size = 10 and filter size = 64, val error is 0.018956855471433463
# Training done in 3.607591152191162
# Training done in 3.555893659591675
# Training done in 3.7012929916381836
# Training done in 3.6123387813568115
# Training done in 3.4960145950317383
# Time for one 5-fold over a pair is 19.00357699394226
# For Layer size = 100 and filter size = 2, val error is 0.1820382382078371
# Training done in 4.100619792938232
# Training done in 4.105569362640381
# Training done in 3.9870128631591797
# Training done in 4.166496992111206
# Training done in 4.009785175323486
# Time for one 5-fold over a pair is 21.412655353546143
# For Layer size = 100 and filter size = 4, val error is 0.06964507813234411
# Training done in 5.078166484832764
# Training done in 5.024886608123779
# Training done in 5.119213104248047
# Training done in 4.977460622787476
# Training done in 5.132139682769775
# Time for one 5-fold over a pair is 26.38441276550293
# For Layer size = 100 and filter size = 8, val error is 0.04127564338966383
# Training done in 6.72566032409668
# Training done in 6.7386634349823
# Training done in 6.783212661743164
# Training done in 6.726675033569336
# Training done in 6.796550750732422
# Time for one 5-fold over a pair is 34.98622941970825
# For Layer size = 100 and filter size = 16, val error is 0.029174801686299177
# Training done in 11.840830326080322
# Training done in 12.082883596420288
# Training done in 11.865278720855713
# Training done in 12.150219440460205
# Training done in 12.140691995620728
# Time for one 5-fold over a pair is 61.16128420829773
# For Layer size = 100 and filter size = 32, val error is 0.02151107085782882
# Training done in 22.036200523376465
# Training done in 22.079163312911987
# Training done in 22.01867127418518
# Training done in 22.022727251052856
# Training done in 22.053407669067383
# Time for one 5-fold over a pair is 111.27403259277344
# For Layer size = 100 and filter size = 64, val error is 0.018284541293359678
# Training done in 3.5787429809570312
# Training done in 3.5789854526519775
# Training done in 3.684056282043457
# Training done in 3.6134793758392334
# Training done in 3.507298469543457
# Time for one 5-fold over a pair is 18.984424352645874
# For Layer size = 1000 and filter size = 2, val error is 0.16805106622990648
# Training done in 4.158872604370117
# Training done in 4.047217845916748
# Training done in 4.0717549324035645
# Training done in 4.142115116119385
# Training done in 4.101225137710571
# Time for one 5-fold over a pair is 21.555320978164673
# For Layer size = 1000 and filter size = 4, val error is 0.07838263155230636
# Training done in 5.052809476852417
# Training done in 5.072695016860962
# Training done in 5.040262937545776
# Training done in 5.014607191085815
# Training done in 5.10983681678772
# Time for one 5-fold over a pair is 26.334526777267456
# For Layer size = 1000 and filter size = 8, val error is 0.03979597370761654
# Training done in 6.786092281341553
# Training done in 6.708072185516357
# Training done in 6.799245595932007
# Training done in 6.757195711135864
# Training done in 6.720189094543457
# Time for one 5-fold over a pair is 34.99539375305176
# For Layer size = 1000 and filter size = 16, val error is 0.029578479438285933
# Training done in 11.856855630874634
# Training done in 12.145135641098022
# Training done in 11.744353294372559
# Training done in 12.153083801269531
# Training done in 12.090008735656738
# Time for one 5-fold over a pair is 61.05936098098755
# For Layer size = 1000 and filter size = 32, val error is 0.02352819417026415
# Training done in 22.021003007888794
# Training done in 22.112191438674927
# Training done in 22.002734899520874
# Training done in 21.97848129272461
# Training done in 22.08977723121643
# Time for one 5-fold over a pair is 111.25323152542114
# For Layer size = 1000 and filter size = 64, val error is 0.018822175701961808
# Time for one 5-fold over all pairs is 822.2562437057495
# For iteration 18, best layer size is 100 and best filter size is 64
# Training done in 27.643704175949097
# Time for 1 cross validation is 850.1104779243469
# Training done in 3.5672082901000977
# Training done in 3.582784652709961
# Training done in 3.663229465484619
# Training done in 3.621720314025879
# Training done in 3.597165107727051
# Time for one 5-fold over a pair is 19.06008291244507
# For Layer size = 10 and filter size = 2, val error is 0.1708787990541684
# Training done in 4.17242431640625
# Training done in 4.101379632949829
# Training done in 4.029839992523193
# Training done in 4.134395122528076
# Training done in 4.066136360168457
# Time for one 5-fold over a pair is 21.547194004058838
# For Layer size = 10 and filter size = 4, val error is 0.08510215776876298
# Training done in 5.094637155532837
# Training done in 5.135472774505615
# Training done in 5.097230434417725
# Training done in 5.10732889175415
# Training done in 5.035346269607544
# Time for one 5-fold over a pair is 26.69503951072693
# For Layer size = 10 and filter size = 8, val error is 0.047458981423230705
# Training done in 6.805900812149048
# Training done in 6.769330263137817
# Training done in 6.865875482559204
# Training done in 6.856613874435425
# Training done in 6.781982421875
# Time for one 5-fold over a pair is 35.13688540458679
# For Layer size = 10 and filter size = 16, val error is 0.03159406613590181
# Training done in 11.863488912582397
# Training done in 12.088732719421387
# Training done in 11.872992515563965
# Training done in 12.132750511169434
# Training done in 12.08471965789795
# Time for one 5-fold over a pair is 61.12486410140991
# For Layer size = 10 and filter size = 32, val error is 0.02245229262931068
# Training done in 22.005163431167603
# Training done in 22.08582854270935
# Training done in 22.11063838005066
# Training done in 22.01759624481201
# Training done in 22.10434103012085
# Time for one 5-fold over a pair is 111.38516402244568
# For Layer size = 10 and filter size = 64, val error is 0.020972894114584452
# Training done in 3.633413076400757
# Training done in 3.601999044418335
# Training done in 3.713378429412842
# Training done in 3.6547036170959473
# Training done in 3.7604503631591797
# Time for one 5-fold over a pair is 19.399609088897705
# For Layer size = 100 and filter size = 2, val error is 0.15771570456501144
# Training done in 4.171494483947754
# Training done in 4.1199469566345215
# Training done in 4.0952746868133545
# Training done in 4.0219948291778564
# Training done in 4.072158098220825
# Time for one 5-fold over a pair is 21.533647537231445
# For Layer size = 100 and filter size = 4, val error is 0.07972400590060089
# Training done in 5.19965124130249
# Training done in 5.099994659423828
# Training done in 5.163735866546631
# Training done in 5.015621662139893
# Training done in 4.9924376010894775
# Time for one 5-fold over a pair is 26.697418689727783
# For Layer size = 100 and filter size = 8, val error is 0.040871604081248944
# Training done in 6.829442024230957
# Training done in 6.682464361190796
# Training done in 6.830212831497192
# Training done in 6.734482526779175
# Training done in 6.719059705734253
# Time for one 5-fold over a pair is 34.86483883857727
# For Layer size = 100 and filter size = 16, val error is 0.0301152099558178
# Training done in 11.805410861968994
# Training done in 12.144737243652344
# Training done in 11.950939178466797
# Training done in 12.170499801635742
# Training done in 12.160744667053223
# Time for one 5-fold over a pair is 61.28424572944641
# For Layer size = 100 and filter size = 32, val error is 0.022990378983447957
# Training done in 21.99383854866028
# Training done in 21.998798847198486
# Training done in 22.106603384017944
# Training done in 22.038612365722656
# Training done in 22.000008821487427
# Time for one 5-fold over a pair is 111.22745108604431
# For Layer size = 100 and filter size = 64, val error is 0.021107573884056086
# Training done in 3.6184542179107666
# Training done in 3.440746784210205
# Training done in 3.6015684604644775
# Training done in 3.5876832008361816
# Training done in 3.6234242916107178
# Time for one 5-fold over a pair is 18.892273664474487
# For Layer size = 1000 and filter size = 2, val error is 0.14479720299947213
# Training done in 4.138078927993774
# Training done in 4.129089117050171
# Training done in 4.014923572540283
# Training done in 4.057416677474976
# Training done in 4.100907325744629
# Time for one 5-fold over a pair is 21.651401042938232
# For Layer size = 1000 and filter size = 4, val error is 0.07770914231584122
# Training done in 5.129715919494629
# Training done in 5.198566913604736
# Training done in 5.186113119125366
# Training done in 4.98310112953186
# Training done in 5.00589919090271
# Time for one 5-fold over a pair is 26.59864091873169
# For Layer size = 1000 and filter size = 8, val error is 0.04853434062954205
# Training done in 6.799291610717773
# Training done in 6.8495423793792725
# Training done in 6.800445795059204
# Training done in 6.792150259017944
# Training done in 6.728453636169434
# Time for one 5-fold over a pair is 35.047226667404175
# For Layer size = 1000 and filter size = 16, val error is 0.029173355460586727
# Training done in 11.796335935592651
# Training done in 12.102967977523804
# Training done in 11.896923065185547
# Training done in 12.187951564788818
# Training done in 12.169163703918457
# Time for one 5-fold over a pair is 61.22109055519104
# For Layer size = 1000 and filter size = 32, val error is 0.022183113868581496
# Training done in 22.026890754699707
# Training done in 21.996803998947144
# Training done in 22.07278823852539
# Training done in 22.12695288658142
# Training done in 22.096446752548218
# Time for one 5-fold over a pair is 111.3888156414032
# For Layer size = 1000 and filter size = 64, val error is 0.021107573884056086
# Time for one 5-fold over all pairs is 824.7588143348694
# For iteration 19, best layer size is 10 and best filter size is 64
# Training done in 27.72090721130371
# Time for 1 cross validation is 852.6907968521118
# Training done in 3.7034759521484375
# Training done in 3.590534210205078
# Training done in 3.6672604084014893
# Training done in 3.6791813373565674
# Training done in 3.5957257747650146
# Time for one 5-fold over a pair is 19.42026424407959
# For Layer size = 10 and filter size = 2, val error is 0.13672735391312524
# Training done in 4.095212697982788
# Training done in 4.094174861907959
# Training done in 4.156466007232666
# Training done in 4.059197187423706
# Training done in 4.150331974029541
# Time for one 5-fold over a pair is 21.616355180740356
# For Layer size = 10 and filter size = 4, val error is 0.0727339450868097
# Training done in 5.131088495254517
# Training done in 5.110751628875732
# Training done in 5.191363334655762
# Training done in 5.151424884796143
# Training done in 5.156292676925659
# Time for one 5-fold over a pair is 26.795634269714355
# For Layer size = 10 and filter size = 8, val error is 0.048397853077929875
# Training done in 6.859874963760376
# Training done in 6.844998598098755
# Training done in 6.924483060836792
# Training done in 6.8540544509887695
# Training done in 6.799440860748291
# Time for one 5-fold over a pair is 35.35132431983948
# For Layer size = 10 and filter size = 16, val error is 0.02608186722201735
# Training done in 11.787501811981201
# Training done in 12.13181757926941
# Training done in 11.86196255683899
# Training done in 12.11486530303955
# Training done in 12.133942127227783
# Time for one 5-fold over a pair is 61.10384511947632
# For Layer size = 10 and filter size = 32, val error is 0.02204816293178875
# Training done in 22.062905311584473
# Training done in 21.985387563705444
# Training done in 22.16045308113098
# Training done in 22.053687572479248
# Training done in 22.028059244155884
# Time for one 5-fold over a pair is 111.34749031066895
# For Layer size = 10 and filter size = 64, val error is 0.019494128323607484
# Training done in 3.7172017097473145
# Training done in 3.646841287612915
# Training done in 3.6646382808685303
# Training done in 3.6367027759552
# Training done in 3.5845208168029785
# Time for one 5-fold over a pair is 19.482797861099243
# For Layer size = 100 and filter size = 2, val error is 0.19466134817160913
# Training done in 4.084839105606079
# Training done in 4.139131784439087
# Training done in 4.158411026000977
# Training done in 4.04489541053772
# Training done in 4.149327754974365
# Time for one 5-fold over a pair is 21.606923818588257
# For Layer size = 100 and filter size = 4, val error is 0.07676665509686094
# Training done in 5.054582357406616
# Training done in 5.076519250869751
# Training done in 5.166066408157349
# Training done in 5.1383655071258545
# Training done in 5.081394910812378
# Time for one 5-fold over a pair is 26.58346652984619
# For Layer size = 100 and filter size = 8, val error is 0.04248369380509216
# Training done in 6.777063369750977
# Training done in 6.7710442543029785
# Training done in 6.7546632289886475
# Training done in 6.874122619628906
# Training done in 6.829774856567383
# Time for one 5-fold over a pair is 35.09217953681946
# For Layer size = 100 and filter size = 16, val error is 0.026753548676341898
# Training done in 11.919718503952026
# Training done in 12.152716398239136
# Training done in 11.836606979370117
# Training done in 12.12851595878601
# Training done in 12.187607049942017
# Time for one 5-fold over a pair is 61.29154300689697
# For Layer size = 100 and filter size = 32, val error is 0.02097280372547745
# Training done in 22.054646015167236
# Training done in 21.99510169029236
# Training done in 22.04946732521057
# Training done in 22.06189489364624
# Training done in 22.067111492156982
# Time for one 5-fold over a pair is 111.45408177375793
# For Layer size = 100 and filter size = 64, val error is 0.018553087330339668
# Training done in 3.7408223152160645
# Training done in 3.566128730773926
# Training done in 3.640216112136841
# Training done in 3.600551128387451
# Training done in 3.6955373287200928
# Time for one 5-fold over a pair is 19.30698299407959
# For Layer size = 1000 and filter size = 2, val error is 0.12651193859325624
# Training done in 4.0816490650177
# Training done in 4.1579625606536865
# Training done in 4.1071882247924805
# Training done in 4.058394432067871
# Training done in 4.15083909034729
# Time for one 5-fold over a pair is 21.60413646697998
# For Layer size = 1000 and filter size = 4, val error is 0.08160997461873876
# Training done in 5.037288665771484
# Training done in 5.109047174453735
# Training done in 5.113163948059082
# Training done in 5.120849609375
# Training done in 4.982636213302612
# Time for one 5-fold over a pair is 26.43033003807068
# For Layer size = 1000 and filter size = 8, val error is 0.040064429355489525
# Training done in 6.857716083526611
# Training done in 6.733519554138184
# Training done in 6.788559913635254
# Training done in 6.80173397064209
# Training done in 6.742732524871826
# Time for one 5-fold over a pair is 34.969735622406006
# For Layer size = 1000 and filter size = 16, val error is 0.028232947191068104
# Training done in 11.739608526229858
# Training done in 12.150521278381348
# Training done in 11.958752393722534
# Training done in 12.08362889289856
# Training done in 12.10922908782959
# Time for one 5-fold over a pair is 61.0917866230011
# For Layer size = 1000 and filter size = 32, val error is 0.02110775466227015
# Training done in 22.07681655883789
# Training done in 22.04620385169983
# Training done in 22.065701961517334
# Training done in 22.004037380218506
# Training done in 22.050743579864502
# Time for one 5-fold over a pair is 111.45335054397583
# For Layer size = 1000 and filter size = 64, val error is 0.019225220730199367
# Time for one 5-fold over all pairs is 826.004930973053
# For iteration 20, best layer size is 100 and best filter size is 64
# Training done in 27.52229928970337
# Time for 1 cross validation is 853.7364385128021

# %%
# Analyse Results
av_val_error = np.mean(all_pair_errors, axis = -1)
# Observe that the filter sizes are chosen in powers to 2 to make the result's difference significant enough. Therefore, it makes sense to also observe the average of the power. Same
# intuition for the layer sizes
best_lsizes = np.array(best_pairs)[:, 0]; best_fsizes = np.array(best_pairs)[:, 1]
best_lsizes_pow = np.log10(best_lsizes); best_fsizes_pow = np.log2(best_fsizes)

# Compute mean and std of the best values
av_lsize = np.mean(best_lsizes); std_lsize = np.std(best_lsizes)
av_fsize = np.mean(best_fsizes); std_fsize = np.std(best_fsizes)

# Compute mean and std of the best powers
av_lsize_pow = np.mean(best_lsizes_pow); std_lsize_pow = np.std(best_lsizes_pow)
av_fsize_pow = np.mean(best_fsizes_pow); std_fsize_pow = np.std(best_fsizes_pow)

# Compute mean and std of the test errors
av_test_error = np.mean(pair_errors); std_test_error = np.std(pair_errors)


# Prints
print(f"The average best hidden layer size is {av_lsize} with std of {std_lsize}")
print(f"The average best filter size is {av_fsize} with std of {std_fsize}")
print(f"The average best hidden layer size power is {av_lsize_pow} with std of {std_lsize_pow}")
print(f"The average best filter size power is {av_fsize_pow} with std of {std_fsize_pow}")
print(f"The average best test error is {av_test_error} with std of {std_test_error}")
# Out:
# The average best hidden layer size is 433.0 with std of 464.2639335550415
# The average best filter size is 64.0 with std of 0.0
# The average best hidden layer size power is 2.1 with std of 0.8306623862918076
# The average best filter size power is 6.0 with std of 0.0
# The average best test error is 0.01690860215053764 with std of 0.0027960866149715244

# %%
# Bar Chart for Layer Size
all_counts = np.zeros((len(layer_sizes)))
lsizes, counts = np.unique(best_lsizes_pow, return_counts = True)
all_counts[np.log10(layer_sizes) == lsizes] = counts

# Plot bar chart
plt.title("Counts of Each Layer Size being Selected as Best")
plt.bar(np.log10(layer_sizes), all_counts)
plt.xlabel('Log10 Layer Size')
plt.ylabel('Counts')
plt.grid()

# %%
# Bar Chart for Layer Size
all_counts = np.zeros((len(filter_banks)))
fsizes, counts = np.unique(best_fsizes_pow, return_counts = True)
all_counts[np.log2(filter_banks) == fsizes] = counts

# Plot bar chart
plt.title("Counts of Each Layer Size being Selected as Best")
plt.bar(np.log2(filter_banks), all_counts)
plt.xlabel('Log2 Filter Size')
plt.ylabel('Counts')
plt.grid()

# %%
# Visualisation of validation performance during cross validations
# Plot 
size_pow = np.log10(np.array(layer_sizes));
fb_pow = np.log2(np.array(filter_banks))
# Test Results
size_powgrid, fb_powgrid = np.meshgrid(size_pow,fb_pow)
fig = plt.figure(figsize = (20,10))
ax = fig.gca(projection='3d')
# ax.set_zlim(0, 30)
ax.set_xlabel("Log10 of Layer Size")
ax.set_yticks(fb_pow)
ax.set_xticks(size_pow)
ax.set_ylim(fb_pow[-1],fb_pow[0])
ax.set_xlim(size_pow[-1],size_pow[0])
ax.set_ylabel("Log2 of Filter Size")
ax.set_zlabel("Average Cross Validation Error")
ax.set_title("Plot of Average Cross Validation Error Rate vs Layer Size and Filter Size")
MSE_surf = ax.plot_surface(size_powgrid, fb_powgrid, (av_val_error.T), cmap = cm.coolwarm, linewidth=0, antialiased=False)
fig.colorbar(MSE_surf, shrink=0.5, aspect=5)

# %%
fig = plt.figure(figsize = (15,8))
heat_map = plt.imshow(np.log(av_val_error), cmap="hot", origin="lower", 
           extent=[fb_pow[0]-0.5, fb_pow[-1]+0.5, size_pow[0]-0.5, size_pow[-1]+0.5])
plt.ylabel("Log10 Layer Size")
plt.yticks(size_pow)
plt.xlabel("Log2 Filter Size")
plt.xticks(fb_pow)
plt.title("Heatmap of Log of Average Cross Validation Errors")
fig.colorbar(heat_map, shrink=0.5, aspect=5)
